# %%
# imports
import requests
from requests_html import HTMLSession, AsyncHTMLSession
from bs4 import BeautifulSoup
import re
import json

# %%
# this function scrapes a github-page for metadata

url1 = 'https://github.com/AlvaroMenduina/Jupyter_Notebooks'
url2 = 'https://github.com/k2inno-tech/jupyter-genomics'
url3 = 'https://github.com/PatrickJS/awesome-angular'
url4 = 'https://github.com/danielmachinelearning/HotelSpamDetection'
url5 = 'https://github.com/ankitkariryaa/ambulanceSiteLocation'

def github_scraper(url):
    meta = {}

    #page = requests.get(url, timeout=None)

    # requests-html is slightly better than requests in catching ajax data (last_commit)
    session = HTMLSession()
    page = session.get(url)

    # requests-html offers rendering javascript-functions
    #asession = AsyncHTMLSession()
    #r = await asession.get(url)
    #await r.html.arender()
    #page = r.html.html

    #print(page)

    soup = BeautifulSoup(page.content, 'html.parser')
    #title = soup.title.text
    #meta['title'] = title

    #print(page.text)
    #print(page.status_code)
    #print(title)

    about = soup.select('p.f4')[0].text.strip()
    # remove emojis, check: https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python
    about = about.encode('ascii', 'ignore').decode('ascii').strip()
    #print(about)
    meta['about'] = about

    #lic = soup.select('div.mt-3')[-1].text.strip()
    lic = soup.select('div.mt-3')
    lic = [elem.text.strip() for elem in lic]
    if len(lic) > 0 and "Readme" in lic:
        readme = lic.index("Readme")
        if readme == len(lic)-1:
            lic = 'Nan'
        else:
            lic = lic[readme+1]
        #print (lic)
        meta['license'] = lic

    lang = soup.select('li.d-inline')
    lang = [elem.text.strip().replace('\n', ': ') for elem in lang]
    #print(lang)
    meta['languages'] = lang

    social = soup.select('a.social-count')
    social = [elem.text.strip() for elem in social]
    #print(social)
    watch, stars, forks = social
    #print(watch, stars, forks)
    #meta['watch'] = watch
    meta['stars'] = stars
    #meta['forks'] = forks

    contributors = soup.select('span.Counter')[-1].text.strip()
    #print(contributors)
    meta['contributors'] = contributors

    commits = soup.find('span', {"aria-label" : re.compile("Commits")}).parent.text.strip().replace('\ncommits', '')
    #print(commits)
    meta['commits'] = commits

    # this in an ajax-element, which often is not fetched
    #last_commit = soup.select('relative-times')
    #if len(last_commit) > 0:
    #    last_commit = last_commit[0].get("datetime")
    #else:
    #    last_commit = 'NaN'

    #last_commit = soup.select('a.link-gray.ml-2')[-1].findChildren()[0].get("datetime")
    #print(last_commit)
    #meta['last_commit'] = last_commit
    
    return meta

meta = github_scraper(url3)
print(json.dumps(meta))
# Out:
# {"about": "A curated list of awesome Angular resources", "license": "CC0-1.0 License", "languages": ["HTML: 74.7%", "CSS: 23.2%", "Shell: 2.1%"], "stars": "7.6k", "contributors": "245", "commits": "588"}

# %%
# traverse csv and scrape all github-repositories
import os
import pandas as pd

git_store = '../data/repositories/git/'
meta_store = '.meta/github_meta.json'
csv = '../data/database/db_03_cleanup.csv'
df = pd.read_csv(csv)

#print(df.head())

# helper function to create folder create_folder
def create_folder(path):
    if not os.path.exists(os.path.dirname(path)):
        try:
            os.makedirs(os.path.dirname(path))
            print(path + ' created')
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
                
for url in df['Base_URL']:
    if 'https://github.com/' in url:
        path = url.replace('https://github.com/','')+'/' #.replace('/','\\')
        print(url)
        
        path_meta = os.path.join(git_store, path, meta_store)
        #print(path_meta)
        
        already_scraped = os.path.isfile(path_meta)
        
        if not already_scraped:
            meta = github_scraper(url)
            #print(json.dumps(meta))

            create_folder(path_meta)
            with open(path_meta, 'w') as fp:
                fp.write(json.dumps(meta))
                
        else:
            print('already scraped')
# Out:
# https://github.com/bschreck/robo-chef
# already scraped
# https://github.com/Ankushr785/Food-amenities-demand-prediction
# already scraped
# https://github.com/catherhuang/FP3-recipe
# already scraped
# https://github.com/stratospark/food-101-keras
# already scraped
# https://github.com/Murgio/Food-Recipe-CNN
# already scraped
# https://github.com/jubins/DeepLearning-Food-Image-Recognition-And-Calorie-Estimation
# already scraped
# https://github.com/Architectshwet/Amazon-Fine-Food-Reviews
# already scraped
# https://github.com/altosaar/food2vec
# already scraped
# https://github.com/gabrielilharco/snap-n-eat
# already scraped
# https://github.com/npatta01/web-deep-learning-classifier
# already scraped
# https://github.com/krpiyush5/Amazon-Fine-Food-Review
# already scraped
# https://github.com/nd1/DC_RestaurantViolationForecasting
# already scraped
# https://github.com/alifier/Restaurant_success_model
# already scraped
# https://github.com/josephofiowa/dc-michelin-challenge
# already scraped
# https://github.com/gzsuyu/Data-Analysis-NYC-Restaurant-Inspection-Data
# already scraped
# https://github.com/gzsuyu/Data-Analysis-NYC-Restaurant-Inspection-Data
# already scraped
# https://github.com/anki1909/Recruit-Restaurant-Visitor-Forecasting
# already scraped
# https://github.com/everAspiring/RegressionAnalysis
# already scraped
# https://github.com/klin90/missinglink
# already scraped
# https://github.com/nvodoor/RBA
# already scraped
# https://github.com/sanatasy/Restaurant_Risk
# already scraped
# https://github.com/Lolonon/Restaurant-Analytical-Solution
# already scraped
# https://github.com/Myau5x/anti-recommender
# already scraped
# https://github.com/bzjin/menus
# already scraped
# https://github.com/rphaneendra/Menu-Similarity
# already scraped
# https://github.com/firmai/interactive-corporate-report
# already scraped
# https://github.com/rochiecuevas/shared_accommodations
# already scraped
# https://github.com/SiddheshAcharekar/Liveright
# already scraped
# https://github.com/nus-usp/room-allocation
# already scraped
# https://github.com/marcotav/hotels
# already scraped
# https://github.com/Montclair-State-University-Info368/Assignment-6
# already scraped
# https://github.com/EliadProject/Hotels-Data-Science
# already scraped
# https://github.com/morenobcn/capstone_hotels_arcpy
# already scraped
# https://github.com/morenobcn/hotels_vs_airbnb_proof_of_concept
# already scraped
# https://github.com/argha48/smarthotels
# already scraped
# https://github.com/Hasan330/Order-Cancellation-Prediction-Model
# already scraped
# https://github.com/danielmachinelearning/HotelSpamDetection
# already scraped
# https://github.com/starfoe/Eye-bnb
# already scraped
# https://github.com/darshankaarki/ml-coa-charging
# already scraped
# https://github.com/GitiHubi/deepAI
# already scraped
# https://github.com/rameshcalamur/fin-stmt-anom
# already scraped
# https://github.com/Niels-Peter/XBRL-AI
# already scraped
# https://github.com/mschermann/forensic_accounting
# already scraped
# https://github.com/CharlesHoffmanCPA/charleshoffmanCPA.github.io
# already scraped
# https://github.com/EricHe98/Financial-Statements-Text-Analysis
# already scraped
# https://github.com/TiesdeKok/Python_NLP_Tutorial/
# already scraped
# https://github.com/TiesdeKok/UW_Python_Camp/
# already scraped
# https://github.com/danshorstein/python4cpas/
# already scraped
# https://github.com/danshorstein/ficpa_article
# already scraped
# https://github.com/deadskull7/Agricultural-Price-Prediction-and-Visualization-on-Android-App
# already scraped
# https://github.com/Vipul115/Statistical-Time-Series-Analysis-on-Agricultural-Commodity-Prices
# already scraped
# https://github.com/DFS-UCU/UkrainianAgriculture
# already scraped
# https://github.com/vicelab/slaer
# already scraped
# https://github.com/gumballhead/mpr
# already scraped
# https://github.com/chrieke/InstanceSegmentation_Sentinel2
# already scraped
# https://github.com/jfzhang95/LSTM-water-table-depth-prediction
# already scraped
# https://github.com/surajmall/Agriculture-Assistant/
# already scraped
# https://github.com/tecoevo/agriculture
# already scraped
# https://github.com/gauravmunjal13/Agriculture
# already scraped
# https://github.com/divyam3897/agriculture
# already scraped
# https://github.com/Paresh3189/Bankruptcy-Prediction-Growth-Modelling
# already scraped
# https://github.com/Featuretools/predict-loan-repayment
# already scraped
# https://github.com/RealRadOne/Gyani-The-Loan-Eligibility-Predictor
# already scraped
# https://github.com/abuchowdhury/Mortgage_Bank_Loan_Analtsics/
# already scraped
# https://github.com/IBM-Cloud-DevFest-2018/Data-Science-for-Banking/
# already scraped
# https://github.com/Brett777/Predict-Risk
# already scraped
# https://github.com/sa7mon/venmo-data
# already scraped
# https://github.com/am-aditya/Artificial-Intelligence-for-Banking/
# already scraped
# https://github.com/am-aditya/Artificial-Intelligence-for-Banking/
# already scraped
# https://github.com/am-aditya/Artificial-Intelligence-for-Banking/
# already scraped
# https://github.com/am-aditya/Artificial-Intelligence-for-Banking/
# already scraped
# https://github.com/sekhansen/mpc_minutes_demo/
# already scraped
# https://github.com/kaumaron/Data_Science/
# already scraped
# https://github.com/eswar3/Zillow-prediction-models
# already scraped
# https://github.com/denadai2/real-estate-neighborhood-prediction
# already scraped
# https://github.com/KSpiliop/Fraud_Detection
# already scraped
# https://github.com/longtng/frauddetectionproject/
# already scraped
# https://github.com/Michaels72/AML-Due-Diligence/
# already scraped
# https://github.com/am-aditya/Artificial-Intelligence-for-Banking/
# already scraped
# https://github.com/neokt/car-damage-detective
# already scraped
# https://github.com/sharmaroshan/Insurance-Claim-Prediction/
# already scraped
# https://github.com/slegroux/claimdenial/
# already scraped
# https://github.com/rshea3/alpha-insurance
# already scraped
# https://github.com/dchannah/fraudhacker
# already scraped
# https://github.com/JSchelldorfer/ActuarialDataScience
# already scraped
# https://github.com/Shomona/Bank-Failure-Prediction/
# already scraped
# https://github.com/andrey-lukyanov/Risk-Management
# already scraped
# https://github.com/hamaadshah/market_risk_gan_keras
# already scraped
# https://github.com/SaiBiswas/Bank-Grievance-Compliance-Management/
# already scraped
# https://github.com/apbecker/Systemic_Risk/
# already scraped
# https://github.com/kaitai/stress-testing-with-jupyter/
# already scraped
# https://github.com/arcadynovosyolov/reverse_stress_testing/
# already scraped
# https://github.com/Karagul/BoE_stress_test/
# already scraped
# https://github.com/hkacmaz/Bankin_Recovery/
# already scraped
# https://github.com/mick-zhang/Quality-Control-for-Banking-using-LDA-and-LDA-Mallet
# already scraped
# https://github.com/govwiki/rating_history
# already scraped
# https://github.com/albahnsen/ML_RiskManagement
# already scraped
# https://github.com/apoorv-goel/Bank-Note-Authentication-Using-DNN-Tensorflow-Classifier-and-RandomForest
# already scraped
# https://github.com/shivangchopra11/InfyHack
# already scraped
# https://github.com/burkesquires/python_biologist
# already scraped
# https://github.com/talmo/leap
# already scraped
# https://github.com/greenelab/SPRINT_gan
# already scraped
# https://github.com/ricket-sjtu/bioinformatics
# already scraped
# https://github.com/waldronlab/AppStatBio
# already scraped
# https://github.com/mingzhangyang/Mybiotools
# already scraped
# https://github.com/mitmedialab/Evolutron
# already scraped
# https://github.com/hallba/WritingSimulators
# already scraped
# https://github.com/jrieke/lstm-biology
# already scraped
# https://github.com/deepchem/deepchem
# already scraped
# https://github.com/ehsanasgari/Deep-Proteomics
# already scraped
# https://github.com/budach/pysster
# already scraped
# https://github.com/hussius/deeplearning-biology
# already scraped
# https://github.com/HIPS/neural-fingerprint
# already scraped
# https://github.com/aspuru-guzik-group/chemical_vae
# already scraped
# https://github.com/gablg1/ORGAN
# already scraped
# https://github.com/MarcusOlivecrona/REINVENT
# already scraped
# https://github.com/deepchem/deepchem
# already scraped
# https://github.com/k2inno-tech/jupyter-genomics
# already scraped
# https://github.com/google/deepvariant
# already scraped
# https://github.com/mila-iqia/gene-graph-conv
# already scraped
# https://github.com/greenelab/adage
# already scraped
# https://github.com/uci-cbcl/D-GEX
# already scraped
# https://github.com/widdowquinn/Teaching-EMBL-Plant-Path-Genomics
# already scraped
# https://github.com/viritaromero/Plant-diseases-classifier
# already scraped
# https://github.com/AayushG159/Plant-Leaf-Identification
# already scraped
# https://github.com/openalea/eartrack
# already scraped
# https://github.com/mfsatya/PlantSeedlings-Classification
# already scraped
# https://github.com/sacul-git/hierarpy
# already scraped
# https://github.com/A7med01/Deep-learning-for-Animal-Identification
# already scraped
# https://github.com/NomaanAhmed/BigData_AnimalSpeciesAnalysis
# already scraped
# https://github.com/timsainb/AVGN
# already scraped
# https://github.com/hardmaru/estool
# already scraped
# https://github.com/OGGM/oggm-edu
# already scraped
# https://github.com/carolineh101/deep-learning-architecture
# already scraped
# https://github.com/damontallen/Construction-materials
# already scraped
# https://github.com/dariusmehri/Social-Network-Bad-Actor-Risk-Tool
# already scraped
# https://github.com/dariusmehri/Geo-Spatial-Risk-Analysis-of-Inspectors
# already scraped
# https://github.com/dariusmehri/Social-Network-Analysis-to-Expose-Corruption
# already scraped
# https://github.com/dariusmehri/Risk-Screening-Tool-to-Predict-Accidents-at-Construction-Sites
# already scraped
# https://github.com/dariusmehri/Algorithm-for-Finding-Buildings-with-Facade-Risk
# already scraped
# https://github.com/dariusmehri/Predicting-Staff-Levels-for-Front-line-Workers
# already scraped
# https://github.com/dariusmehri/Topic-Modeling-and-Analysis-of-Building-Related-Injuries
# already scraped
# https://github.com/dariusmehri/Predictive-Analysis-of-Building-Violations
# already scraped
# https://github.com/dariusmehri/Inspection-Productivity-Analysis-and-Visualization-with-Tableau
# already scraped
# https://github.com/ritchie46/anaStruct
# already scraped
# https://github.com/buddyd16/Structural-Engineering
# already scraped
# https://github.com/JorgeDeLosSantos/nusa
# already scraped
# https://github.com/BrianChevalier/StructPy
# already scraped
# https://github.com/albiboni/AileronSimulation
# already scraped
# https://github.com/vibrationtoolbox/vibration_toolbox
# already scraped
# https://github.com/ebrahimraeyat/Civil
# already scraped
# https://github.com/manuvarkey/Gestimator
# already scraped
# https://github.com/Gunnstein/fatpack
# already scraped
# https://github.com/yajnab/pySteel
# already scraped
# https://github.com/davidsteinar/structural-uncertainty
# already scraped
# https://github.com/jellespijker/pymech
# already scraped
# https://github.com/AlvaroMenduina/Jupyter_Notebooks/
# already scraped
# https://github.com/psi4/psi4numpy
# already scraped
# https://github.com/CAChemE/learn
# already scraped
# https://github.com/iurisegtovich/PyTherm-applied-thermodynamics
# already scraped
# https://github.com/kshitizkhanal7/Aerogami
# already scraped
# https://github.com/geoscixyz/em-apps
# already scraped
# https://github.com/mdeff/pygsp_tutorial_graphsip
# already scraped
# https://github.com/DocVaughan/MCHE485---Mechanical-Vibrations
# already scraped
# https://github.com/OpenChemE/CHBE356
# already scraped
# https://github.com/rdbraatz/data-driven-prediction-of-battery-cycle-life-before-capacity-degradation
# already scraped
# https://github.com/DTUWindEnergy/Python4WindEnergy
# already scraped
# https://github.com/openeemeter/eemeter/
# already scraped
# https://github.com/HitarthiShah/Radiation-Data-Analysis
# already scraped
# https://github.com/materialsproject/pymatgen/
# already scraped
# https://github.com/dchannah/materials_mining
# already scraped
# https://github.com/materialsproject/emmet
# already scraped
# https://github.com/materialsvirtuallab/megnet
# already scraped
# https://github.com/hackingmaterials/atomate
# already scraped
# https://github.com/Mehranov/UnderstandingAndPredictingPropertyMaintenanceFines/
# already scraped
# https://github.com/sierraporta/asphalt_binder
# already scraped
# https://github.com/hbutsuak95/Quality-Optimization-of-Steel
# already scraped
# https://github.com/tilde-lab/awesome-materials-informatics
# already scraped
# https://github.com/tradingeconomics/tradingeconomics
# already scraped
# https://github.com/jhconning/Dev-II/
# already scraped
# https://github.com/lnsongxf/Applied_Computational_Economics_and_Finance/
# already scraped
# https://github.com/jlperla/ECON407_2018
# already scraped
# https://github.com/microsoft/EconML
# already scraped
# https://github.com/saisrivatsan/deep-opt-auctions
# already scraped
# https://github.com/jstac/quantecon_nyu_2016
# already scraped
# https://github.com/zhentaoshi/econ5170
# already scraped
# https://github.com/QuantEcon/columbia_mini_course
# already scraped
# https://github.com/jstac/econometrics/
# already scraped
# https://github.com/sharmaroshan/Education-Process-Mining
# already scraped
# https://github.com/janzaib-masood/Educational-Data-Mining
# already scraped
# https://github.com/RohithYogi/Student-Performance-Prediction
# already scraped
# https://github.com/sharmaroshan/Students-Performance-Analytics
# already scraped
# https://github.com/eloyekunle/student_intervention/
# already scraped
# https://github.com/arrahman17/Learning-Analytics-Project-
# already scraped
# https://github.com/janzaib-masood/Educational-Data-Mining
# already scraped
# https://github.com/kaumaron/Data_Science/
# already scraped
# https://github.com/nprapps/school-choice
# already scraped
# https://github.com/tullyvelte/SchoolPerformanceDataAnalysis
# already scraped
# https://github.com/bradleyrobinson/School-Performance
# already scraped
# https://github.com/vtyeh/pandas-challenge
# already scraped
# https://github.com/benattix/philly-schools
# already scraped
# https://github.com/adrianakopf/NJPublicSchools
# already scraped
# https://github.com/whugue/school-closure
# already scraped
# https://github.com/datacamp/course-resources-ml-with-experts-budgets/
# already scraped
# https://github.com/nymarya/school-budgets-for-education/
# already scraped
# https://github.com/JonathanREB/Budget_SchoolsAnalysis/
# already scraped
# https://github.com/1davegalloway/SchoolDistrictAnalysis
# already scraped
# https://github.com/jinsonfernandez/NLP_School-Budget-Project
# already scraped
# https://github.com/DivyaMadhu/School-Budget-Prediction
# already scraped
# https://github.com/sushant2811/SchoolBudgetData/
# already scraped
# https://github.com/kaumaron/Data_Science/
# already scraped
# https://github.com/aeronetlab/emergency-mapping
# already scraped
# https://github.com/roshetty/Supporting-Emergency-Room-Decision-Making-with-Relevant-Scientific-Literature
# already scraped
# https://github.com/mesgarpour/T-CARER
# already scraped
# https://github.com/LeadingIndiaAI/Forest-Fire-Detection-through-UAV-imagery-using-CNNs
# already scraped
# https://github.com/sky-t/hack-or-emergency-response
# already scraped
# https://github.com/bayesimpact/bayeshack-transportation-ems
# already scraped
# https://github.com/jamesypeng/Smarter-Emergency-Dispatch
# already scraped
# https://github.com/analystiu/LICT-Project-Emergency-911-Calls
# already scraped
# https://github.com/tanoybhattacharya/911-Data-Analysis
# already scraped
# https://github.com/amunategui/Leak-At-Chemical-Factory-RL
# already scraped
# https://github.com/datadesk/lapd-crime-classification-analysis
# already scraped
# https://github.com/chicago-justice-project/article-tagging
# already scraped
# https://github.com/chrisPiemonte/crime-analysis
# already scraped
# https://github.com/RandomFractals/ChicagoCrimes
# already scraped
# https://github.com/pedrohserrano/graph-analytics-nederlands
# already scraped
# https://github.com/vikram-bhati/PAASBAAN-crime-prediction
# already scraped
# https://github.com/tina31726/Crime-Prediction
# already scraped
# https://github.com/felzek/Crime-Review-Data-Analysis
# already scraped
# https://github.com/benjaminsingleton/crime-trends
# already scraped
# https://github.com/cmenguy/crime-analytics
# already scraped
# https://github.com/kaiareyes/ambulance
# already scraped
# https://github.com/ankitkariryaa/ambulanceSiteLocation
# already scraped
# https://github.com/DimaStoyanov/Ambulance-Dispatching
# already scraped
# https://github.com/scngo/SD-ambulance-allocation
# already scraped
# https://github.com/nonsignificantp/ambulance-response-time
# already scraped
# https://github.com/aditink/EMSRouting
# already scraped
# https://github.com/Polichinel/Master_Thesis
# already scraped
# https://github.com/Polichinel/Master_Thesis
# already scraped
# https://github.com/ab-bh/Disease-Outbreak-Prediction/
# already scraped
# https://github.com/leportella/federal-road-accidents
# already scraped
# https://github.com/rajaswa/Disaster-Management-
# already scraped
# https://github.com/paultopia/concrete_NLP_tutorial/
# already scraped
# https://github.com/arijitsaha/FloodRisk
# already scraped
# https://github.com/Senkichi/The_Catastrophe_Coefficient
# already scraped
# https://github.com/DLColumbia/DL_forFinance
# already scraped
# https://github.com/borisbanushev/stockpredictionai/
# already scraped
# https://github.com/ishank011/gs-quantify-bond-prediction
# already scraped
# https://github.com/chenbowen184/Computational_Finance
# already scraped
# https://github.com/SeanMcOwen/FinanceAndPython.com-ClusteringIndustries
# already scraped
# https://github.com/MiyainNYC/Financial-Modeling/
# already scraped
# https://github.com/MAydogdu/TextualAnalysis
# already scraped
# https://github.com/chen-bowen/Data_Science_in_Applied_Corporate_Finance
# already scraped
# https://github.com/sarachmax/MarketCrashes_Prediction/
# already scraped
# https://github.com/chen-bowen/Research_Documents_Curation_with_NLP
# already scraped
# https://github.com/imhgchoi/Corr_Prediction_ARIMA_LSTM_Hybrid
# already scraped
# https://github.com/SeanMcOwen/FinanceAndPython.com-Investments
# already scraped
# https://github.com/SeanMcOwen/FinanceAndPython.com-Derivatives
# already scraped
# https://github.com/SeanMcOwen/FinanceAndPython.com-BasicFinance
# already scraped
# https://github.com/jjakimoto/finance_ml
# already scraped
# https://github.com/aluo417/Financial-Engineering-Projects
# already scraped
# https://github.com/LongOnly/Quantitative-Notebooks
# already scraped
# https://github.com/bukosabino/financial-forecasting-challenge-gresearch
# already scraped
# https://github.com/rawillis98/alpaca
# already scraped
# https://github.com/arcadynovosyolov/finance
# already scraped
# https://github.com/joelowj/Machine-Learning-and-Reinforcement-Learning-in-Finance
# already scraped
# https://github.com/mbravidor/PyDSout
# already scraped
# https://github.com/duncangh/FSA
# already scraped
# https://github.com/tradeasystems/tradeasystems_connector
# already scraped
# https://github.com/pzivich/zEpid
# already scraped
# https://github.com/pzivich/Python-for-Epidemiologists
# already scraped
# https://github.com/rjhere/Prescription-compliance-prediction
# already scraped
# https://github.com/alistairwallace97/olympian-biotech
# already scraped
# https://github.com/callysto/curriculum-notebooks/
# already scraped
# https://github.com/LexPredict/lexpredict-contraxsuite
# already scraped
# https://github.com/davidawad/lobe
# already scraped
# https://github.com/hockeyjudson/Legal-Entity-Detection/
# already scraped
# https://github.com/Law-AI/summarization
# already scraped
# https://github.com/GirrajMaheshwari/Web-scrapping-/
# already scraped
# https://github.com/akarazeev/LegalTech
# already scraped
# https://github.com/propublica/congress-api-docs
# already scraped
# https://github.com/toningega/Data_Generator
# already scraped
# https://github.com/brightmart/ai_law
# already scraped
# https://github.com/t-davidson/hate-speech-and-offensive-language
# already scraped
# https://github.com/erickjtorres/AI_LegalDoc_Hackathon
# already scraped
# https://github.com/siddhantmaharana/text-analysis-on-FINRA-docs
# already scraped
# https://github.com/davidsontheath/bias_corrected_estimators/
# already scraped
# https://github.com/anshu3769/FirmEmbeddings
# already scraped
# https://github.com/Kevin-McIsaac/Nightlife
# https://github.com/ProximaDas/nlp-govt-regulations
# https://github.com/philxchen/Clustering-Canadian-regulations
# https://github.com/ds-modules/EEP-147
# https://github.com/vsub21/systemic-risk-dashboard
# https://github.com/raymond180/FINRA_TRACE
# https://github.com/davidmasse/US-supreme-court-prediction
# https://github.com/AccelAI/AI-Law-Minicourse/
# https://github.com/GirrajMaheshwari/Legal-Analytics-project---Court-misclassification
# https://github.com/whs2k/GPO-AI
# https://github.com/brightmart/sentiment_analysis_fine_grain
# https://github.com/Danila89/kaggle_mercedes
# https://github.com/Meena-Mani/SECOM_class_imbalance
# https://github.com/usnistgov/modelmeth
# https://github.com/han-yan-ds/Kaggle-Bosch
# https://github.com/Azure/lstms_for_predictive_maintenance
# https://github.com/Samimust/predictive-maintenance
# https://github.com/m-hoff/maintsim
# https://github.com/LaranIkal/ProductAnomaliesDetection
# https://github.com/IBM/iot-predictive-analytics
# https://github.com/sharmaroshan/SECOM-Detecting-Defected-Items
# https://github.com/jorgehas/smart-defect-inspection
# https://github.com/aayushmudgal/Reducing-Manufacturing-Failures
# https://github.com/mohan-mj/Manufacturing-Line-I4.0
# https://github.com/buzz11/productionFailures
# https://github.com/limberc/tianchi-IMQF
# https://github.com/trentwoodbury/ManufacturingAuctionRegression
# https://github.com/andrei-rizoiu/hip-popularity
# https://github.com/hathix/youtube-transcriber
# https://github.com/byukan/Marketing-Data-Science
# https://github.com/ikatsov/algorithmic-examples
# https://github.com/HowardNTUST/Marketing-Data-Science-Application
# https://github.com/mikhailklassen/Mining-the-Social-Web-3rd-Edition/
# https://github.com/ivan-bilan/Painting_Forensics
# https://github.com/xiaofei6677/TourismFlickrMiner
# https://github.com/khanhnamle1994/fashion-recommendation
# https://github.com/yiaktan/Secondhand_Concert_Tickets
# https://github.com/jerryxyx/EquineTrading
# https://github.com/fvisconti/gammas_machine_learning
# https://github.com/callysto/curriculum-notebooks/
# already scraped
# https://github.com/higgsfield/interaction_network_pytorch
# https://github.com/hep-lbdl/adversarial-jets
# https://github.com/ernestyalumni/CompPhys
# https://github.com/robmarkcole/Useful-python-for-medical-physics
# https://github.com/pymedphys/pymedphys
# https://github.com/FPAL-Stanford-University/FloATPy
# https://github.com/dkirkby/MachineLearningStatistics
# https://github.com/arogozhnikov/hep_ml
# https://github.com/hep-lbdl/CaloGAN
# https://github.com/GiggleLiu/marburg
# https://github.com/dssg/triage
# https://github.com/worldbank/ML-classification-algorithms-poverty/
# https://github.com/avsolatorio/world-bank-pover-t-tests-solution
# https://github.com/Global-Witness/overseas-companies-land-ownership/
# https://github.com/MAydogdu/ConsumerFinancialProtectionBureau/
# https://github.com/tslindner/Effects-of-Cannabis-Legalization
# https://github.com/dmodjeska/barnet_transactions/
# https://github.com/shayanray/GlassBox/
# https://github.com/Featuretools/predict-household-poverty
# https://github.com/ancilcrayton/nlp_public_policy
# https://github.com/sharmaroshan/World-Food-Production
# https://github.com/DataScienceForGood/TaxationInequality
# https://github.com/austinbrian/sheriffs
# https://github.com/MengchuanFu/Suspecious-Apps-Detection
# https://github.com/farkhondehm/Social-Assistance
# https://github.com/abjer/sds/
# https://github.com/bhaveshgoyal/safeLiquor
# https://github.com/austinpetsalive/distemper-outbreak
# https://github.com/ryanschaub/The-U.S.-Mexican-Border-Wall-and-Staffing-A-Statistical-Approach-
# https://github.com/zischwartz/workerfatalities
# https://github.com/fpli-mbr/LA-Parking-Tickets
# https://github.com/DistrictDataLabs/city-dash
# https://github.com/johnfwhitesell/CensusPull/
# https://github.com/datakind/datadive-gates92y-proj3-form990
# https://github.com/Chris-Manna/charity_recommender
# https://github.com/staceb/charities_in_the_united_states
# https://github.com/LauraChen/02-Metis-Web-Scraping
# https://github.com/Akesari12/LS123_Data_Prediction_Law_Spring-2019/
# https://github.com/sfbrigade/datasci-campaign-finance/
# https://github.com/nealmcb/pr_voting_methods
# https://github.com/austinbrian/portfolio/
# https://github.com/kaumaron/Data_Science/
# already scraped
# https://github.com/okfn-brasil/perfil-politico
# https://github.com/ParticipaPY/politic-bots
# https://github.com/PrincetonUniversity/gerrymandertests
# https://github.com/JulianMar11/SentimentPoliticalCompass
# https://github.com/muntisa/Deep-Politics
# https://github.com/edmundooo/more-money-more-problems
# https://github.com/abhiagar90/power_networks
# https://github.com/philippschmalen/Project_tsds
# https://github.com/kkirchhoff01/DebateAnalysis
# https://github.com/davidjwiner/political_affiliation_prediction
# https://github.com/philiplbean/facebook_political_ads
# https://github.com/pgromano/Political-Identity-Analysis
# https://github.com/kmunger/YT_descriptive
# https://github.com/albertwebson/Political-Vector-Projector
# https://github.com/GretelDePaepe/FindingDonuts
# https://github.com/denadai2/real-estate-neighborhood-prediction
# already scraped
# https://github.com/Sardhendu/PropertyClassification
# https://github.com/hyattsaleh15/RealStateRecommender
# https://github.com/Shreyas3108/house-price-prediction
# https://github.com/girishkuniyal/Predict-housing-prices-in-Portland
# https://github.com/eswar3/Zillow-prediction-models
# already scraped
# https://github.com/denadai2/real-estate-neighborhood-prediction
# already scraped
# https://github.com/ual/rental-listings
# https://github.com/mratsim/Apartment-Interest-Prediction
# https://github.com/awoziji/pwc_europe_data_analytics_hackathon
# https://github.com/Featuretools/predict-household-poverty
# already scraped
# https://github.com/luqmanhakim/research-on-sp-wholesale/
# https://github.com/richardddli/state_electricity_rates
# https://github.com/datadesk/california-electricity-capacity-analysis
# https://github.com/PyPSA/WHOBS
# https://github.com/pipette/Electricity-load-disaggregation
# https://github.com/farwacheema/DA-electricity-price-forecasting
# https://github.com/gschivley/carbon-index
# https://github.com/hvantil/ElectricityDemandForecasting
# https://github.com/un-modelling/Electricity_Consumption_Surveys
# https://github.com/amirrezaeian/Individual-household-electric-power-consumption-Data-Set-
# https://github.com/Open-Power-System-Data/renewable_power_plants
# https://github.com/FUSED-Wind/FUSED-Wake
# https://github.com/YungChunLu/UCI-Power-Plant
# https://github.com/samarthiith/DE_CoalPhaseOut
# https://github.com/Jean-njoroge/coal-exploratory/
# https://github.com/sdasadia/Oil-Natural-Gas-Price-Prediction
# https://github.com/cep-kse/natural_gas_formula
# https://github.com/victorpena1/Natural-Gas-Demand-Prediction
# https://github.com/williamadams1/natural-gas-consumption-forecasting
# https://github.com/bahuisman/NatGasModel
# https://github.com/llSourcell/mapo
# https://github.com/codeforboston/safe-water
# https://github.com/mroberge/hydrofunctions
# https://github.com/sentinel-hub/water-observatory-backend
# https://github.com/wassname/pipe-segmentation
# https://github.com/awracms/awra_cms_older
# https://github.com/datadesk/california-ccscore-analysis
# https://github.com/cadrev/lstm-flood-prediction
# https://github.com/johnpfay/USWaterAccounting
# https://github.com/txytju/air-quality-prediction
# https://github.com/xinychen/transdim
# https://github.com/AlanConstantine/KDD-Cup-2019-CAMMTR
# https://github.com/CityofToronto/bdit_data-sources
# https://github.com/pawelmorawiecki/traffic_jam_Nairobi
# https://github.com/Lemma1/DPFE
# https://github.com/hackoregon/2019-transportation-data-science
# https://github.com/nishanthgampa/Time-Series-Analysis-on-Transportation-Data
# https://github.com/fangshulin/Vulnerability-Analysis-for-Transportation-Networks
# https://github.com/akpen/Stockholm-0.1
# https://github.com/crowdAI/train-schedule-optimisation-challenge-starter-kit
# https://github.com/mratsim/McKinsey-SmartCities-Traffic-Prediction
# https://github.com/Data4Democracy/crash-model
# https://github.com/llSourcell/AI_Supply_Chain
# https://github.com/cavaunpeu/flight-delays
# https://github.com/pratishthakapoor/RetailReplenishement/
# https://github.com/kralmachine/WholesaleCustomerAnalysis
# https://github.com/Semionn/JB-wholesale-distribution-analysis
# https://github.com/prakhardogra921/Clustering-Analysis-on-customers-of-a-wholesale-distributor
# https://github.com/tstreamDOTh/Instacart-Market-Basket-Analysis
# https://github.com/SarahMestiri/online-retail-case
# https://github.com/sharmaroshan/Online-Retail-Transactions-of-UK
# https://github.com/IBM-DSE/CyberShop-Analytics
# https://github.com/arvindkarir/retail
# https://github.com/finnqiao/cohort_online_retail
# https://github.com/datadesk/california-electricity-capacity-analysis
# already scraped
# https://github.com/PyPSA/WHOBS
# already scraped
# https://github.com/pipette/Electricity-load-disaggregation
# already scraped
# https://github.com/farwacheema/DA-electricity-price-forecasting
# already scraped
# https://github.com/gschivley/carbon-index
# already scraped
# https://github.com/hvantil/ElectricityDemandForecasting
# already scraped
# https://github.com/un-modelling/Electricity_Consumption_Surveys
# already scraped
# https://github.com/amirrezaeian/Individual-household-electric-power-consumption-Data-Set-
# already scraped
# https://github.com/Open-Power-System-Data/renewable_power_plants
# already scraped
# https://github.com/FUSED-Wind/FUSED-Wake
# already scraped
# https://github.com/YungChunLu/UCI-Power-Plant
# already scraped
# https://github.com/samarthiith/DE_CoalPhaseOut
# already scraped
# https://github.com/Jean-njoroge/coal-exploratory/
# already scraped
# https://github.com/sdasadia/Oil-Natural-Gas-Price-Prediction
# already scraped
# https://github.com/cep-kse/natural_gas_formula
# already scraped
# https://github.com/victorpena1/Natural-Gas-Demand-Prediction
# already scraped
# https://github.com/williamadams1/natural-gas-consumption-forecasting
# already scraped
# https://github.com/bahuisman/NatGasModel
# already scraped
# https://github.com/codeforboston/safe-water
# already scraped
# https://github.com/mroberge/hydrofunctions
# already scraped
# https://github.com/sentinel-hub/water-observatory-backend
# already scraped
# https://github.com/wassname/pipe-segmentation
# already scraped
# https://github.com/awracms/awra_cms_older
# already scraped
# https://github.com/datadesk/california-ccscore-analysis
# already scraped
# https://github.com/cadrev/lstm-flood-prediction
# already scraped
# https://github.com/johnpfay/USWaterAccounting
# already scraped
# https://github.com/txytju/air-quality-prediction
# already scraped
# https://github.com/xinychen/transdim
# already scraped
# https://github.com/AlanConstantine/KDD-Cup-2019-CAMMTR
# already scraped
# https://github.com/CityofToronto/bdit_data-sources
# already scraped
# https://github.com/pawelmorawiecki/traffic_jam_Nairobi
# already scraped
# https://github.com/Lemma1/DPFE
# already scraped
# https://github.com/hackoregon/2019-transportation-data-science
# already scraped
# https://github.com/nishanthgampa/Time-Series-Analysis-on-Transportation-Data
# already scraped
# https://github.com/fangshulin/Vulnerability-Analysis-for-Transportation-Networks
# already scraped
# https://github.com/akpen/Stockholm-0.1
# already scraped
# https://github.com/crowdAI/train-schedule-optimisation-challenge-starter-kit
# already scraped
# https://github.com/mratsim/McKinsey-SmartCities-Traffic-Prediction
# already scraped
# https://github.com/Data4Democracy/crash-model
# already scraped
# https://github.com/llSourcell/AI_Supply_Chain
# already scraped
# https://github.com/cavaunpeu/flight-delays
# already scraped
# https://github.com/pratishthakapoor/RetailReplenishement/
# already scraped
# https://github.com/kralmachine/WholesaleCustomerAnalysis
# already scraped
# https://github.com/Semionn/JB-wholesale-distribution-analysis
# already scraped
# https://github.com/prakhardogra921/Clustering-Analysis-on-customers-of-a-wholesale-distributor
# already scraped
# https://github.com/tstreamDOTh/Instacart-Market-Basket-Analysis
# already scraped
# https://github.com/SarahMestiri/online-retail-case
# already scraped
# https://github.com/sharmaroshan/Online-Retail-Transactions-of-UK
# already scraped
# https://github.com/IBM-DSE/CyberShop-Analytics
# already scraped
# https://github.com/arvindkarir/retail
# already scraped
# https://github.com/finnqiao/cohort_online_retail
# already scraped

# %%
# github_api_scraper

url1 = 'https://github.com/AlvaroMenduina/Jupyter_Notebooks'
url2 = 'https://github.com/k2inno-tech/jupyter-genomics'
url3 = 'https://github.com/PatrickJS/awesome-angular'
url4 = 'https://github.com/danielmachinelearning/HotelSpamDetection'
url5 = 'https://github.com/ankitkariryaa/ambulanceSiteLocation'
url6 = 'https://github.com/TiesdeKok/Python_NLP_Tutorial/'

def github_api_scraper(url):
    api_url = 'https://api.github.com/repos/'
    meta = {}
    url = api_url + url.replace('https://github.com/','')

    page = requests.get(url, timeout=None)
    status = page.status_code
    if status == 200:
        raw = json.loads(page.content)

        meta['description'] = raw['description']
        meta['created_at'] = raw['created_at']
        meta['pushed_at'] = raw['pushed_at']
        meta['homepage'] = raw['homepage']
        meta['size'] = raw['size']
        meta['stars'] = raw['stargazers_count']
        meta['language'] = raw['language']
        if raw['license'] == None:
            meta['license'] = 'NaN'
        else:
            meta['license'] = raw['license']['name']

        return meta
    
    else:
        return None

meta = github_api_scraper(url5)
print(meta)
# Out:
# {'description': None, 'created_at': '2018-10-21T12:15:59Z', 'pushed_at': '2018-10-29T16:30:20Z', 'homepage': None, 'size': 27606, 'stars': 0, 'language': 'Jupyter Notebook', 'license': 'NaN'}

# %%
git_store = '../data/repositories/git/'
meta_store = '.meta/github_api_meta.json'
csv = '../data/database/db_03_cleanup.csv'
df = pd.read_csv(csv)

#print(df.head())

# helper function to create folder create_folder
def create_folder(path):
    if not os.path.exists(os.path.dirname(path)):
        try:
            os.makedirs(os.path.dirname(path))
            print(path + ' created')
        except OSError as exc: # Guard against race condition
            if exc.errno != errno.EEXIST:
                raise
                
i = 0
for url in df['Base_URL']:
    if 'https://github.com/' in url:
        path = url.replace('https://github.com/','')+'/' #.replace('/','\\')
        #print(url)
        
        path_meta = os.path.join(git_store, path, meta_store)
        #print(path_meta)
        
        already_scraped = os.path.isfile(path_meta)
        
        if not already_scraped:
            print(url)
            i += 1
            meta = github_api_scraper(url)
            
            if meta != None:
                #print(json.dumps(meta))

                create_folder(path_meta)
                with open(path_meta, 'w') as fp:
                    fp.write(json.dumps(meta))
            
            else:
                print('An Error occured')
                #break
                create_folder(path_meta)
                with open(path_meta, 'w') as fp:
                    fp.write(json.dumps({}))
                
        #else:
        #    print('already scraped')
            
    if i == 60:
        print('Quota exceeded')
        break
# Out:
# https://github.com/akpen/Stockholm-0.1
# https://github.com/crowdAI/train-schedule-optimisation-challenge-starter-kit
# https://github.com/mratsim/McKinsey-SmartCities-Traffic-Prediction
# https://github.com/Data4Democracy/crash-model
# https://github.com/llSourcell/AI_Supply_Chain
# https://github.com/cavaunpeu/flight-delays
# https://github.com/pratishthakapoor/RetailReplenishement/
# An Error occured
# https://github.com/kralmachine/WholesaleCustomerAnalysis
# https://github.com/Semionn/JB-wholesale-distribution-analysis
# https://github.com/prakhardogra921/Clustering-Analysis-on-customers-of-a-wholesale-distributor
# https://github.com/tstreamDOTh/Instacart-Market-Basket-Analysis
# https://github.com/SarahMestiri/online-retail-case
# https://github.com/sharmaroshan/Online-Retail-Transactions-of-UK
# https://github.com/IBM-DSE/CyberShop-Analytics
# https://github.com/arvindkarir/retail
# https://github.com/finnqiao/cohort_online_retail
