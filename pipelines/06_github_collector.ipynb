# %% [markdown]
# ## GitHub Meta Collector
#
# This script collects all meta-information derived by the individuall parsers
# collected data will be stored in a .csv-file inside ./data/database/

# %%
import os
import time
import json
import platform
import time
import math
import sys
import datetime
import numpy as np
import pandas as pd

# %%
# scoring function to get a score between 0...1 for integer-values, 0.5 should be at ~100
def score(n, precision=3):
    if isinstance(n, int) or isinstance(i, float):
        return round(1-1/math.pow(1+n, 0.15), precision)
    else:
        return 0

for n in [0,1,10,25,50,100,1000,10000]:
    print(score(n))
# Out:
# 0.0
# 0.099
# 0.302
# 0.387
# 0.446
# 0.5
# 0.645
# 0.749

# %%
# get file modifictaion date
# https://stackoverflow.com/questions/237079/how-to-get-file-creation-modification-date-times-in-python

def creation_date(path_to_file, datetime = True):
    """
    Try to get the date that a file was created, falling back to when it was
    last modified if that isn't possible.
    See http://stackoverflow.com/a/39501288/1709587 for explanation.
    """
    if platform.system() == 'Windows':
        timestamp = os.path.getctime(path_to_file)
    else:
        stat = os.stat(path_to_file)
        try:
            timestamp = stat.st_birthtime
        except AttributeError:
            # We're probably on Linux. No easy way to get creation dates here,
            # so we'll settle for when its content was last modified.
            timestamp = stat.st_mtime
        
    if datetime == True:
        timestamp = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(timestamp))

    return timestamp
    
folder_base = '../data/repositories/kaggle/competitions/c/'
folder = '3d-object-detection-for-autonomous-vehicles/notebooks/asimandia/lyft3d-inference-kernel/'
notebook = 'notebook_02.html'
kernel = 'kernel.html'
print(creation_date(folder_base+folder+notebook))
# Out:
# 2020-12-12 16:08:03

# %%
# improved version (full text scan)
# scan text for predefined terms

text = 'We use LSTM for anomaly and object detection. As Convolutional Neural Networks are great for ML.'

pd_ml_terms = pd.read_csv('../data/patterns/ml_terms.csv')
ml_terms = pd_ml_terms['Term'].tolist()
ml_slugs = pd_ml_terms['Slug'].tolist()
ml_slugs = [x for x in ml_slugs if str(x) != 'nan']
ml_tags = pd_ml_terms['Tag'].tolist()
ml_tags = [x for x in ml_tags if str(x) != 'nan']

#print(ml_tags)

ml_libs = pd.read_csv('../data/patterns/ml_libraries.csv')
ml_libs = ml_libs['Python Package'].tolist()

def match_text(haystack, needles, toLower = False, unique = True):
    
    if toLower == True:
        haystack = haystack.lower()
        needles = [x.lower() for x in needles]
    
    if unique == True:
        matches = {x for x in needles if x in haystack}
        matches = list(matches)
    else:
        matches = [x for x in needles if x in haystack]
    
    return matches

def match_tags(haystack):
    df = pd.read_csv('../data/patterns/ml_terms.csv')
    tags = []
    
    df.set_index('Term', inplace = True)
    for item in haystack:
        try:
            tag = df.loc[item].get('Tag').head(1)
            if not 'nan' in str(tag):
                tags.append(tag)
        except:
            pass
        
    df.set_index('Slug', inplace = True)
    for item in haystack:
        try:
            tag = df.loc[item]
            if not 'nan' in str(tag):
                tags.append(str(tag))
        except:
            pass
        
    #if 'ANN' in tags or 'CNN' in tags or 'RNN' in tags:
    #    tags.remove('NN')
    
    return list(tags)

#ml_slugs, ml_terms, ml_libs, match_text(haystack, needles, toLower = False, unique = True)
needles = {
    'ml_slugs': ml_slugs,
    'ml_terms': ml_terms,
    'ml_libs': ml_libs,
}
needles_need_str_lower = {
    'ml_slugs': False,
    'ml_terms': True,
    'ml_libs': False,
}

matches = []

matches.extend(match_text(text, ml_terms, True))
matches.extend(match_text(text, ml_slugs, False))
print('matches', matches)

tags = match_tags(matches)
print('tags', tags)

tags_test = ['ML', 'NLP', 'classif', 'convolutional neural network', 'decision tree', 'layer', 'machine learning', 'model', 'naive bayes', 'natural language processing', 'neural network', 'predict', 'regression', 'train']
print(match_tags(tags_test))
# Out:
# matches ['object detection', 'anomaly', 'neural network', 'detect', 'lstm', 'convolutional neural network', 'ML']
# tags ['Tag    ML\nName: ML, dtype: object']
# ['Tag    ML\nName: ML, dtype: object', 'Tag    NLP\nName: NLP, dtype: object']

# %%
# bundle collected data and store in single json-file
# suitable for database building
dir_base = '../data/repositories/git/'

# blobcity
dir_base = '../data/repositories/blobcity/git/'

json_files = {
    'additional_info': '.meta/additional_info.json',
    # 'git_analyzer': '.meta/git_analyzer_results.json',
    'git_analyzer': '.meta/git_analyzer_results_v02.json',
    'github_api': '.meta/github_api_meta.json',
    'github_meta': '.meta/github_meta.json',
}
date_ref_file = '.meta/log_clone.txt'

meta_collection = '.meta/summary.json'

authors = os.listdir(dir_base)

p = 0

start = 0
end = 5000

runtime_start = time.time()

i = start
for author in authors:
    if os.path.isdir(os.path.join(dir_base, author)):
        
        projects = os.listdir(os.path.join(dir_base, author))
        #print(author, projects)
        for project in projects:
            #print(project)
            if p >= start:
                path = os.path.join(dir_base, author, project)
                if os.path.isdir(path):
                    print('### ' + str(i) + ': ' + author, project.strip())
                    raw_json = {}
                    
                    # load json files
                    for key in json_files:
                        #print(key, json_files[key])
                        json_fp = os.path.join(path, json_files[key])
                        if os.path.isfile(json_fp):
                            with open(json_fp, 'r') as fp:
                                data = fp.read()
                                raw_json[key] = json.loads(data)
                        else:
                            raw_json[key] = {}

                    # readme
                    readme_fp = os.path.join(path, 'README.md')
                    if os.path.isfile(readme_fp):
                        with open(readme_fp, 'r', encoding='utf-8', errors="ignore") as fp:
                            readme = fp.read()
                    else:
                        readme = ''
                        
                    # combine ml_libs and keywords
                    ml_libs = []
                    ml_terms = []
                    ml_tags = []
                    
                    for file in raw_json['git_analyzer']:
                        #print(file)
                        #print(file['meta']['ml_libs'])
                        if file['meta'].get('ml_libs'):
                            ml_libs.extend(file['meta'].get('ml_libs'))
                        if file['meta'].get('keywords'):
                            ml_terms.extend(file['meta'].get('keywords'))
                        if file['meta'].get('ml_tags'):
                            ml_tags.extend(file['meta'].get('ml_tags'))
                    
                    # make values unique
                    ml_libs = np.unique(ml_libs).tolist()
                    ml_terms = np.unique(ml_terms).tolist()
                    ml_tags = np.unique(ml_tags).tolist()
                    #ml_tags = match_tags(ml_terms)
                    
                    # parse created_at
                    created_at = raw_json['github_api'].get('created_at')
                    if created_at != None:
                        created_at = created_at.replace('T',' ').replace('Z','')
                    
                    # get pushed_at
                    pushed_at = raw_json['github_api'].get('pushed_at')
                    if pushed_at == None:
                        pushed_at = raw_json['github_meta'].get('last_commit')
                    if pushed_at == None:
                        pushed_at = ''
                    
                    # 2018-07-25T04:01:33Z
                    pushed_at = pushed_at.replace('T',' ').replace('Z','')
                    #date_time_str = pushed_at.split('Z')
                    #date_time_str = date_time_str[0].strip()
                    #date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%dT%H:%M:%S')
                    #pushed_at = date_time_obj
                    #print(pushed_at)
                    
                    # get scraped_at
                    ref_fp = os.path.join(dir_base, author, project)
                    ref_fp += '/' + date_ref_file
                    if os.path.isfile(ref_fp):
                        scraped_at = creation_date(ref_fp)
                    else:
                        scraped_at = creation_date(path)
                    
                    # get primary language
                    language_primary = raw_json['github_api'].get('language')
                    if language_primary == None:
                        language_primary = raw_json['github_meta'].get('languages')
                        if language_primary != None and len(language_primary) > 0:
                            language_primary = language_primary[0].split(':')[0]
                        else:
                            language_primary = ''
                    #print(language_primary)
                    
                    # parse description
                    description = raw_json['github_meta'].get('about')
                    if description != None:
                        description = description.replace(';', '.')
                        description = description.replace('\n', ' ').replace('\r', '')
                        description = description.replace('<br/>', '').replace('<br>', '')
                        
                    # parse readme
                    if readme != None:
                        readme = readme.replace(';', '.')
                        readme = readme.replace('\n', ' ').replace('\r', '')
                        #readme = readme.replace('<br/>', '').replace('<br>', '')
                    
                    # build ml score
                    ml_detected = 0; #len(ml_libs) > 0 or len(keywords) > 0
                    if len(ml_terms) > 0:
                        ml_detected += 0.2
                    if len(ml_tags) > 0:
                        ml_detected += 0.3
                    if len(ml_libs) > 0:
                        ml_detected += 0.5
                        
                    # parse license
                    license = raw_json['github_meta'].get('license')
                    if license != None:
                        if 'Nan' in license:
                            license = ''
                        if 'View license' in license:
                            license = ''
                        if '+ ' in license:
                            license = ''
                        if 'License' in license:
                            license = license.replace('License','').strip()
                    
                    # build final json
                    final_json = {
                        'author': author,
                        'title': project,
                        'link': raw_json['github_meta'].get('url'),
                        'ml_detected': ml_detected,
                        'description': description,
                        'license': license,
                        'language_primary': language_primary,
                        'languages': raw_json['github_meta'].get('languages'),
                        'created_at': created_at,
                        'pushed_at': str(pushed_at),
                        'scraped_at': str(scraped_at),
                        'stars': raw_json['github_api'].get('stars'),
                        'stars_score': score(raw_json['github_api'].get('stars')),
                        'contributors': raw_json['github_meta'].get('contributors'),
                        'ml_libs': ml_libs,
                        'ml_tags': ml_tags,
                        'ml_terms': ml_terms,
                        'readme': readme,
                        'industry': raw_json['additional_info'].get('industry'),
                        'type': raw_json['additional_info'].get('type'),
                        'name': raw_json['additional_info'].get('name'),
                        'description2': raw_json['additional_info'].get('description'),
                        #'raw': raw_json,
                    }
                    #print(final_json)
                    
                    # store final json
                    with open(os.path.join(path, meta_collection), 'w') as fp:
                        fp.write(json.dumps(final_json))
                    
                # count parsed projects
                i += 1

            # count projects
            p += 1
        
    # break loop
    if i>=end and True:
        break
    
runtime_end = time.time()
print('### parsed {0} git-projects  in {1} seconds ###'.format(i-start, round(runtime_end - runtime_start, 3)))
# Out:
# ### 0: 0xGG crossnote
# ### 1: 0xGG welcome-notebook
# ### 2: 1024hub Go-Learning-Notebook
# ### 3: 583 machine_learning_notebook
# ### 4: a415432669 -front_end_notebook
# ### 5: aaren notedown
# ### 6: abdullah768 icpc_notebook
# ### 7: abhinavsagar kaggle-notebooks
# ### 8: abhishekkrthakur colabcode
# ### 9: abhshkdz HackFlowy
# ### 10: abulbasar machine-learning
# ### 11: acamposxp Google-Colab-CloudTorrent
# ### 12: acgeospatial Satellite_Imagery_Python
# ### 13: aflaxman pymc-examples
# ### 14: agermanidis pigeon
# ### 15: ageron handson-ml
# ### 16: ageron handson-ml2
# ### 17: ageron julia_notebooks
# ### 18: ageron tf2_course
# ### 19: agile-geoscience notebooks
# ### 20: agiliq notebooks
# ### 21: AiswaryaSrinivas DataScienceWithPython
# ### 22: ajwdewit pcse_notebooks
# ### 23: akabe ocaml-jupyter
# ### 24: alchemyst Dynamics-and-Control
# ### 25: aleen42 PersonalWiki
# ### 26: alexamici covid-19-notebooks
# ### 27: alexcfleming Python_DL_Working_Notebooks
# ### 28: algorithmiaio awesome-ipython-notebooks
# ### 29: Alireza-Akhavan rnn-notebooks
# ### 30: allegroai trains-jupyter-plugin
# ### 31: altair-viz altair-tutorial
# ### 32: altair-viz altair_notebooks
# ### 33: amitsaha jupyter-notebook-slides
# ### 34: amueller introduction_to_ml_with_python
# ### 35: amueller scikit-learn-interactive-tutorial
# ### 36: Anaconda-Platform nbpresent
# ### 37: andfanilo pyspark-tutorial
# ### 38: andrashee meteor-notebook-theme
# ### 39: AndrewChau learn-gremlin-jupyter-notebook
# ### 40: andrewray iocaml
# ### 41: aneesha SiameseBERT-Notebook
# ### 42: ANL-DIGR notebooks
# ### 43: ansible ansible-jupyter-kernel
# ### 44: anurag fastai-course-1
# ### 45: apache submarine
# ### 46: apache zeppelin
# ### 47: aparrish rwet
# ### 48: aqibsaeed Human-Activity-Recognition-using-CNN
# ### 49: araffin rl-tutorial-jnrr19
# ### 50: arapfaik scraping-glassdoor-selenium
# ### 51: asfadmin asf-jupyter-notebooks
# ### 52: asharifiz Probability_Statistics
# ### 53: atcemgil notes
# ### 54: atlas-outreach-data-tools notebooks
# ### 55: auduno deepdraw
# ### 56: Auquan Tutorials
# ### 57: austin-taylor code-vault
# ### 58: AustinRochford notebooks
# ### 59: Autodesk molecular-design-toolkit
# ### 60: Autodesk notebook-molecular-visualization
# ### 61: aviaryan SublimeNotebook
# ### 62: aviaryan VSCodeNotebook
# ### 63: aws amazon-sagemaker-examples
# ### 64: aws-samples amazon-a2i-sample-jupyter-notebooks
# ### 65: aws-samples amazon-forecast-samples
# ### 66: aws-samples amazon-personalize-samples
# ### 67: aws-samples amazon-sagemaker-notebook-instance-lifecycle-config-samples
# ### 68: aws-samples aws-open-data-analytics-notebooks
# ### 69: aws-samples sagemaker-run-notebook
# ### 70: Axelrod-Python Axelrod-notebooks
# ### 71: azer notebook
# ### 72: Azure Azure-Sentinel-Notebooks
# ### 73: Azure MachineLearningNotebooks
# ### 74: Azure OpenDatasetsNotebooks
# ### 75: Azure-Samples cosmos-notebooks
# ### 76: Azure-Samples MachineLearningSamples-Notebooks
# ### 77: barbagroup AeroPython
# ### 78: barbagroup CFDPython
# ### 79: bboylin MyNotebook
# ### 80: beader mlnotebook
# ### 81: benjaminwilson python-clustering-exercises
# ### 82: BenLangmead ads1-notebooks
# ### 83: betatim notebook-as-pdf
# ### 84: bgruening docker-jupyter-notebook
# ### 85: bhargavvader personal
# ### 86: bhattbhavesh91 time_series_notebooks
# ### 87: big-data-europe docker-hadoop-spark-workbench
# ### 88: big-data-europe docker-spark-notebook
# ### 89: bikz05 ipython-notebooks
# ### 90: biocore American-Gut
# ### 91: biolab ipynb
# ### 92: biom262 biom262-2016
# ### 93: bip-unh-python jupyter_notebooks
# ### 94: biplobsd OneClickRun
# ### 95: Bitwise-01 Notebook
# ### 96: BlackArbsCEO Mixture_Models
# ### 97: bobthecat codebox
# ### 98: bokeh bokeh-notebooks
# ### 99: bokeh jupyter_bokeh
# ### 100: bqplot bqplot
# ### 101: BrambleXu pydata-notebook
# ### 102: brendan-rius jupyter-c-kernel
# ### 103: briandalessandro DataScienceCourse
# ### 104: brianwarehime threatnote
# ### 105: Bridgewater scala-notebook
# ### 106: BritneyMuller colab-notebooks
# ### 107: brunow NoteItIOS
# ### 108: BUStools BUS_notebooks_python
# ### 109: c1mone Tensorflow-101
# ### 110: caicloud ciao
# ### 111: california-civic-data-coalition first-python-notebook
# ### 112: Calysto conx-notebooks
# ### 113: Calysto notebook-extensions
# ### 114: cameroncruz notebooks
# ### 115: cantaro86 Financial-Models-Numerical-Methods
# ### 116: Cantera cantera-jupyter
# ### 117: captainsafia blazoract
# ### 118: carlosfab data_science
# ### 119: castorini anserini-notebooks
# ### 120: CavsZhouyou Front-End-Interview-Notebook
# ### 121: cboettig labnotebook
# ### 122: ccniuj python_data_science_and_machine_learning_bootcamp
# ### 123: cedrickchee data-science-notebooks
# ### 124: cellardoor42 whatever
# ### 125: censusreporter notebooks
# ### 126: ceos-seo data_cube_notebooks
# ### 127: cerlymarco MEDIUM_NoteBook
# ### 128: cgoliver Notebooks
# ### 129: ChadFulton tsa-notebooks
# ### 130: chainer-community chainer-colab-notebook
# ### 131: chambliss Notebooks
# ### 132: chengxy-nds Springboot-Notebook
# ### 133: chhao01 notebook
# ### 134: chhayac Machine-Learning-Notebooks
# ### 135: chmp ipytest
# ### 136: chris1610 pbpython
# ### 137: ChrisRackauckas JupyterSite
# ### 138: ChristianFJung NotebookToWebApp
# ### 139: christophebourguignat notebooks
# ### 140: CJWorkbench cjworkbench
# ### 141: cliburn sta-663-2017
# ### 142: CODAIT covid-notebooks
# ### 143: codeneuro notebooks
# ### 144: codenode codenode
# ### 145: coderefinery jupyter
# ### 146: coderefinery jupyter-retired
# ### 147: coding-dream Notebook
# ### 148: codingforentrepreneurs Notebooks
# ### 149: COGS108 Tutorials
# ### 150: cokepluscarbon Java
# ### 151: colour-science colour-notebooks
# ### 152: ComPlat chemotion_ELN
# ### 153: compodoc compodoc
# ### 154: Computational-Content-Analysis-2020 Content-Analysis-2020
# ### 155: computationalmodelling nbval
# ### 156: conda-forge notebook-feedstock
# ### 157: ContextLab hypertools-paper-notebooks
# ### 158: Cr0wTom Mi-Notebook-Pro-Mods
# ### 159: crimx ext-saladict
# ### 160: Cryoris notebooks
# ### 161: cs109-energy iPython-Notebook
# ### 162: csaid polished_notebooks
# ### 163: csaluja JupyterNotebooks-Medium
# ### 164: ctgk PRML
# ### 165: cuttlefishh python-for-data-analysis
# ### 166: cxhernandez ipymol
# ### 167: d2l-ai 1day-notebooks
# ### 168: d2l-ai d2l-book
# ### 169: d2l-ai d2l-en
# ### 170: d2l-ai d2l-zh
# ### 171: d2l-ai notebooks
# ### 172: dafang notebook
# ### 173: dair-ai notebooks
# ### 174: daliansky XiaoMi-Pro-Hackintosh
# ### 175: danielfrg jupyter-flex
# ### 176: danielfrg pelican-jupyter
# ### 177: daniestevez jupyter_notebooks
# ### 178: danijar handout
# ### 179: danilobellini notebooks
# ### 180: dannguyen python-notebooks-data-wrangling
# ### 181: DaoCloud python-ipython-notebook
# ### 182: dask dask-examples
# ### 183: dask old-dask-examples
# ### 184: DataBiosphere leonardo
# ### 185: databricks tech-talks
# ### 186: datacite notebooks
# ### 187: datadesk notebooks
# ### 188: dataflowr notebooks
# ### 189: DataScienceUWL DS775v2
# ### 190: datitran jupyter2slides
# ### 191: davidasboth blog-notebooks
# ### 192: davidbp lxmls-notebooks
# ### 193: DavidCai1993 nodejs-api-doc
# ### 194: davidgengenbach vgg-caffe
# ### 195: davidsbatista machine-learning-notebooks
# ### 196: DB2-Samples db2jupyter
# ### 197: dc-aichara DS-ML-Public
# ### 198: dcavar python-tutorial-notebooks
# ### 199: DEAP notebooks
# ### 200: deep-learning-indaba indaba-2018
# ### 201: deepmipt dp_notebooks
# ### 202: deepsense-ai pydatawarsaw-notebooks
# ### 203: DefensePointSecurity threat_note
# ### 204: DeltaAnalytics machine_learning_for_good
# ### 205: dennyglee databricks
# ### 206: dfinke PowerShellNotebook
# ### 207: dformoso sklearn-classification
# ### 208: dgkim5360 the-elements-of-statistical-learning-notebooks
# ### 209: dgokondra stepik_notebooks
# ### 210: dgokondra stepik_pandas_notebooks.github.io
# ### 211: diegoinacio computer-vision-notebooks
# ### 212: differential-machine-learning notebooks
# ### 213: digitalearthafrica deafrica-sandbox-notebooks
# ### 214: diljeet1994 Python_Tutorials
# ### 215: dingzhe NoteBook
# ### 216: DJCordhose deep-learning-crash-course-notebooks
# ### 217: dmonn dcgan-oreilly
# ### 218: dnc1994 Kaggle-Playground
# ### 219: dnote dnote
# ### 220: dongdonghy Detection-PyTorch-Notebook
# ### 221: donnemartin data-science-ipython-notebooks
# ### 222: Dpananos GetCards
# ### 223: draperjames one-dark-notebook
# ### 224: drckf mlreview_notebooks
# ### 225: drillan jupyter-black
# ### 226: DriverPackSolution DP_Notebook
# ### 227: DrSkippy Data-Science-45min-Intros
# ### 228: Dsantra92 Julia-on-Colab
# ### 229: dudash openshift-workshops
# ### 230: dudeperf3ct DL_Notebooks
# ### 231: Dunedan mbp-2016-linux
# ### 232: dunovank jupyter-themes
# ### 233: dvorka mindforger
# ### 234: Dyakonov notebooks
# ### 235: dylanmei docker-zeppelin
# ### 236: dyweb papers-notebook
# ### 237: eclarson DataMiningNotebooks
# ### 238: eclarson MachineLearningNotebooks
# ### 239: ecmwf notebook-examples
# ### 240: ecosme38 Data-Assimilation-Notebooks
# ### 241: edbullen nltk
# ### 242: edvardHua Articles
# ### 243: eee2047s-uct notebooks
# ### 244: ehmatthes intro_programming
# ### 245: Einsteinish Artificial-Neural-Networks-with-Jupyter
# ### 246: Einsteinish bogotobogo-Machine-Learning
# ### 247: eka-foundation numerical-computing-is-fun
# ### 248: elabftw elabftw
# ### 249: elegant-scipy notebooks
# ### 250: elyra-ai elyra
# ### 251: elyra-ai kfp-notebook
# ### 252: Emergent-Behaviors-in-Biology mlreview_notebooks
# ### 253: emmettgb Emmetts-DS-NoteBooks
# ### 254: empathy87 The-Elements-of-Statistical-Learning-Python-Notebooks
# ### 255: empet Plotly-plots
# ### 256: enakai00 jupyter_tfbook
# ### 257: equinor segyio-notebooks
# ### 258: eranif Notebook
# ### 259: erhwenkuo deep-learning-with-keras-notebooks
# ### 260: ericmjl bayesian-analysis-recipes
# ### 261: ernestorx es-swapi-test
# ### 262: erykml medium_articles
# ### 263: espnet notebook
# ### 264: executablebooks jupyter-book
# ### 265: Exely CSAPP-Labs
# ### 266: explosion spacy-notebooks
# ### 267: falloutdurham beginners-pytorch-deep-learning
# ### 268: fastai book_nbs
# ### 269: fastai fastbook
# ### 270: fastai fastdoc
# ### 271: fastai fastpages
# ### 272: fastai fastprogress
# ### 273: fastai nbdev
# ### 274: fastai numerical-linear-algebra
# ### 275: fastai numerical-linear-algebra-v2
# ### 276: fastmachinelearning hls4ml-tutorial
# ### 277: FayeL37 python_notebook
# ### 278: fchollet deep-learning-with-python-notebooks
# ### 279: FCTweedie NLTK
# ### 280: federicoiosue Omni-Notes
# ### 281: felixcheung spark-notebook-examples
# ### 282: feyeleanor GoNotebook
# ### 283: fhoffa notebooks
# ### 284: fhsinchy docker-handbook-projects
# ### 285: fhsinchy kubernetes-handbook-projects
# ### 286: firmai awesome-google-colab
# ### 287: firmai industry-machine-learning
# ### 288: FKLC Torrent-To-Google-Drive-Downloader
# ### 289: flexxui flexx-notebooks
# ### 290: floydhub tensorflow-notebooks-examples
# ### 291: fluentpython notebooks
# ### 292: fonsp Pluto.jl
# ### 293: foobarto redteam-notebook
# ### 294: foodish learning_notebook
# ### 295: FourSpaces notebook
# ### 296: fperez nipy-notebooks
# ### 297: FrancescoSaverioZuppichini Tensorflow-Dataset-Tutorial
# ### 298: frostney react-native-create-library
# ### 299: fsprojects IfSharp
# ### 300: FugroRoames RoamesNotebooks
# ### 301: fwalch tum-thesis-latex
# ### 302: gabehollombe-aws jupyter-notebooks
# ### 303: gammapy gammapy-extra
# ### 304: gaoxuesong KerasNotebook
# ### 305: gboeing urban-data-science
# ### 306: gclouduniverse notebooks-ci-showcase
# ### 307: gdsaxton PANDAS
# ### 308: gee-community ee-tensorflow-notebooks
# ### 309: GEMScienceTools notebooks
# ### 310: geohot ai-notebooks
# ### 311: GeoscienceAustralia dea-notebooks
# ### 312: GeostatisticsLessons GeostatisticsLessonsNotebooks
# ### 313: Germey Python3NoteBooks
# ### 314: getmrinal ML-Notebook
# ### 315: GFigure pydata-notebook
# ### 316: giswqs earthengine-py-notebooks
# ### 317: giswqs Learning-Python
# ### 318: gitmagistere notebook
# ### 319: glouppe notebooks
# ### 320: glushchenko fsnotes
# ### 321: googleanalytics bigquery-export-ipython-notebooks
# ### 322: GoogleCloudPlatform ipython-soccer-predictions
# ### 323: googledatalab notebooks
# ### 324: gopala-kr notebooks
# ### 325: gopherdata gophernotes
# ### 326: gpuopenanalytics demo-docker
# ### 327: grantathon crypto_portfolio_analysis
# ### 328: gsurma image_classifier
# ### 329: guanguans notes
# ### 330: guillaume-chevalier How-to-Grow-Neat-Software-Architecture-out-of-Jupyter-Notebooks
# ### 331: gururajang Notebooks_SparkML
# ### 332: gzc CLRS
# ### 333: gzuidhof starboard-notebook
# ### 334: hackmdio hackmd-desktop
# ### 335: hadrienj Preprocessing-for-deep-learning
# ### 336: hangtwenty dive-into-machine-learning
# ### 337: hans ipython-notebooks
# ### 338: HanXiaoyang Kaggle_Titanic
# ### 339: hardmaru pytorch_notebooks
# ### 340: harusametime sagemaker-notebooks
# ### 341: HazyResearch cs145-notebooks-2016
# ### 342: hdean83 notebook
# ### 343: hemanta212 blogger-cli
# ### 344: hirschmann nbfc
# ### 345: holdenweb int-py-notes
# ### 346: Holy-Shine Pytorch-notebook
# ### 347: home-assistant home-assistant-notebooks
# ### 348: hortonworks-gallery ambari-zeppelin-service
# ### 349: hortonworks-gallery zeppelin-notebooks
# ### 350: HotBitmapGG gank.io-unofficial-android-client
# ### 351: huanghantao study-note
# ### 352: huggingface 100-times-faster-nlp
# ### 353: huggingface notebooks
# ### 354: hughbien notebook
# ### 355: hunkim effective_python_notebook
# ### 356: hunters-forge bloodhound-notebooks
# ### 357: Hvass-Labs FinanceOps
# ### 358: HVF franchise
# ### 359: hxuaj Beauty-of-Mathematics-Notebook
# ### 360: hyperspy hyperspy-demos
# ### 361: ianlewis tensorflow-examples
# ### 362: ianmcloughlin jupyter-teaching-notebooks
# ### 363: iArunava Python-TheNoTheoryGuide
# ### 364: IBM elasticsearch-spark-recommender
# ### 365: IBM nodejs-in-notebooks
# ### 366: IBM starcraft2-replay-analysis
# ### 367: ibm-et jupyter-samples
# ### 368: IBMDataScience sample-notebooks
# ### 369: IBMDataScience SparkSummitDemo
# ### 370: ibrahimsharaf doc2vec
# ### 371: IceEnd Yosoro
# ### 372: ideonate nb2xls
# ### 373: IDR idr-notebooks
# ### 374: iiSeymour Flasked-Notebooks
# ### 375: IMEplusplus icpc-notebook
# ### 376: inaimathi cl-notebook
# ### 377: indentlabs notebook
# ### 378: inetfuture technote
# ### 379: influenist Mi-NB-Gaming-Laptop-MacOS
# ### 380: inkandswitch livebook
# ### 381: INSAlgo ICPC-Notebook
# ### 382: InsightDataLabs ipython-notebooks
# ### 383: InsightLab data-science-cookbook
# ### 384: InsightSoftwareConsortium SimpleITK-Notebooks
# ### 385: iodide-project iodide-examples
# ### 386: ioos notebooks_demos
# ### 387: ipfs notes
# ### 388: ipython ipython
# ### 389: ipython paper-notebook2013
# ### 390: ipython-contrib jupyter_contrib_nbextensions
# ### 391: iRuxu notebook
# ### 392: ivanov ipython-vimception
# ### 393: jaceklaskowski spark-streaming-notebook
# ### 394: jacobstallone D3-in-Jupyter-Notebook
# ### 395: jadianes data-science-your-way
# ### 396: jadianes spark-py-notebooks
# ### 397: jadianes spark-r-notebooks
# ### 398: jakemdrew DataMiningNotebooks
# ### 399: jakevdp ipywidgets-static
# ### 400: jakevdp PythonDataScienceHandbook
# ### 401: jakevdp WhirlwindTourOfPython
# ### 402: jalammar simpleTensorFlowClassificationExample
# ### 403: JalanJiang leetcode-notebook
# ### 404: jaltekruse OpenNotebook
# ### 405: jamalmoir notebook_playground
# ### 406: jamesdbrock learn-you-a-haskell-notebook
# ### 407: JasonKessler Scattertext-PyData
# ### 408: jasonniebauer Nmap-Cheatsheet
# ### 409: jasonstrimpel PyData-Meetup
# ### 410: jaybosamiya security-notes
# ### 411: jayboxyz deeplearning_cv_notes
# ### 412: jaygambetta my-notebooks
# ### 413: jbagnato machine-learning
# ### 414: jbwhit berkeley-jupyter-notebook
# ### 415: jdwittenauer ipython-notebooks
# ### 416: JeanKossaifi tensorly-notebooks
# ### 417: jerry-git learn-python3
# ### 418: jessepisel 5minutesofpython
# ### 419: jessstringham notebooks
# ### 420: jg8610 multi-task-part-1-notebook
# ### 421: jianghui-galaxy Interview-Notebook
# ### 422: Jiasm notebook
# ### 423: jiffyclub ipythonblocks
# ### 424: jkfitzsimons IPyNotebook_MachineLearning
# ### 425: jkitchin ox-ipynb
# ### 426: jldowns google_earth_engine_notebook
# ### 427: jmportilla Statistics-Notes
# ### 428: jmportilla Udemy---Machine-Learning
# ### 429: jmportilla Udemy-notes
# ### 430: jmschrei notebooks
# ### 431: jmsteinw Notebooks
# ### 432: JoelOtter kajero
# ### 433: JohnLaTwC Shared
# ### 434: johnnync13 EFI-Xiaomi-Notebook-air-12-5
# ### 435: johnnync13 Xiaomi-Notebook-Air-1Gen
# ### 436: johnymontana nlp-graph-notebooks
# ### 437: jonkrohn tf2
# ### 438: jonmmease plotly_ipywidget_notebooks
# ### 439: JonyEpsilon gorilla-repl
# ### 440: Joshuaek NotebookScheduler
# ### 441: jpcolino IPython_notebooks
# ### 442: jperkel example_notebook
# ### 443: jpmorganchase jupyterlab_templates
# ### 444: jrjohansson qutip-lectures
# ### 445: jrjohansson scientific-python-lectures
# ### 446: jrjohansson sympsi-notebooks
# ### 447: jseabold csc432-notebooks
# ### 448: JsonChao Awesome-Android-Notebook
# ### 449: jstac econometrics
# ### 450: jsvine nbpreview
# ### 451: jsvine notebookjs
# ### 452: jtpio p5-jupyter-notebook
# ### 453: juanklopper JuliaCourseNotebooks
# ### 454: juanklopper MIT_OCW_Linear_Algebra_18_06
# ### 455: JuliaOpt juliaopt-notebooks
# ### 456: julienr ipynb_playground
# ### 457: jupyter atom-notebook
# ### 458: jupyter docker-stacks
# ### 459: jupyter jupyter-drive
# ### 460: jupyter nbconvert
# ### 461: jupyter nbdime
# ### 462: jupyter nbformat
# ### 463: jupyter nbgrader
# ### 464: jupyter nbviewer
# ### 465: jupyter notebook
# ### 466: jupyter tmpnb
# ### 467: jupyter-attic docker-notebook
# ### 468: jupyter-attic jupyter-js-notebook
# ### 469: Jupyter-contrib jupyter_nbextensions_configurator
# ### 470: jupyter-on-openshift jupyter-notebooks
# ### 471: jupyter-widgets ipywidgets
# ### 472: jupytercalpoly jupyterlab-interactive-dashboard-editor
# ### 473: jupyterhub jupyter-server-proxy
# ### 474: jupyterhub jupyterhub
# ### 475: jupyterhub systemdspawner
# ### 476: jupyterlab debugger
# ### 477: jupyterlab jupyterlab-celltags
# ### 478: justmarkham pandas-videos
# ### 479: justmarkham scikit-learn-videos
# ### 480: jwagemann 2019_egu_workshop_jupyter_notebooks
# ### 481: jwkvam jupyterlab-vim
# ### 482: kaburelabs Datacamp-Courses
# ### 483: kadamwhite wp-notebook
# ### 484: kaixindelele tensorflow_notebook
# ### 485: kaleko CourseraML
# ### 486: karpathy randomfun
# ### 487: KeithGalli NumPy
# ### 488: KelvinJin iSwift
# ### 489: Kennytian learning-react-native
# ### 490: ketch numerical_linear_algebra_notebooks
# ### 491: ketch teaching-numerics-with-notebooks
# ### 492: kevindewalt ai-notebooks
# ### 493: KhanShaheb34 Data-Structures-and-Algorithms-Notebook
# ### 494: khiner notebooks
# ### 495: kirbs- hide_code
# ### 496: kirit93 NumpyTutorial
# ### 497: kirkhas zeppelin-notebooks
# ### 498: kite8 Quantopian-lectures-notebook-translation
# ### 499: kleinee jns
# ### 500: klemag pydata_nyc2018-intro-to-model-interpretability
# ### 501: kmahelona ipython_notebook_goodies
# ### 502: KnowledgeLab content_analysis
# ### 503: kokes nbviewer.js
# ### 504: krasserm bayesian-machine-learning
# ### 505: krasserm machine-learning-notebooks
# ### 506: krischer seismo_live
# ### 507: krishnamrith12 NotebooksNLP
# ### 508: krishnan-r sparkmonitor
# ### 509: krittikaiitb tutorials
# ### 510: kriyeng yolo-on-colab-notebook
# ### 511: kth-competitive-programming kactl
# ### 512: kubeflow kubeflow
# ### 513: kwinkunks notebooks
# ### 514: KxSystems mlnotebooks
# ### 515: kylemcdonald AudioNotebooks
# ### 516: kylemcdonald ml-notebook
# ### 517: kynan nbstripout
# ### 518: LambdaSchool DS-Unit-1-Sprint-1-Dealing-With-Data
# ### 519: lanyuancom lanyuan-notebook-3.1v
# ### 520: Lasagne Recipes
# ### 521: learn-co-students jupyter-notebook-introduction-data-science-intro-000
# ### 522: learnbyexample scripting_course
# ### 523: LearningJournal Spark-Tutorials
# ### 524: lebinh vietnamese-accent-model
# ### 525: ledmaster notebooks_tutoriais
# ### 526: Leemoonsoo zeppelin-examples
# ### 527: leetcode-notebook leetcode-notebook.github.io
# ### 528: LeiG Applied-Predictive-Modeling-with-Python
# ### 529: leondgarse Atom_notebook
# ### 530: leonvanbokhorst NoteBooks-Statistics-and-MachineLearning
# ### 531: leriomaggio python-in-a-notebook
# ### 532: lernapparat lernapparat
# ### 533: lia-statsletters notebooks
# ### 534: liangxiaofei1100 notebook
# ### 535: lightning-viz lightning-example-notebooks
# ### 536: lihd1003 notebook
# ### 537: likejazz jupyter-notebooks
# ### 538: litaotao IPython-Dashboard
# ### 539: liviu- notebooks
# ### 540: liyanage ipython-notebook
# ### 541: lmarti evolutionary-computation-course
# ### 542: lmcinnes umap_paper_notebooks
# ### 543: lmoroney dlaicourse
# ### 544: lmullen rmd-notebook
# ### 545: lnishan Notebook
# ### 546: LongOnly Quantitative-Notebooks
# ### 547: longyincug Notebook
# ### 548: loudinthecloud pytorch-ntm
# ### 549: lspvic jupyter_tensorboard
# ### 550: LSSTC-DSFP LSSTC-DSFP-Sessions
# ### 551: luispedro python-image-tutorial
# ### 552: lyhue1991 spark_tutorial
# ### 553: m2dsupsdlclass lectures-labs
# ### 554: maartenbreddels ipyvolume
# ### 555: maartenbreddels ipywebrtc
# ### 556: maasg spark-notebooks
# ### 557: MaayanLab clustergrammer-widget
# ### 558: MaayanLab Zika-RNAseq-Pipeline
# ### 559: MalayAgarwal-Lee real_python_data_cleaning_tutorial
# ### 560: man-group notebooker
# ### 561: mandli intro-numerical-methods
# ### 562: mandli numerical-methods-pdes
# ### 563: mangecoeur ipython-desktop
# ### 564: manujeevanprakash Matplot-lib-Basics
# ### 565: mapbox mapboxgl-jupyter
# ### 566: marcosvidal Sketch-Notebook
# ### 567: MarkBaggett GeoLocationNotebook
# ### 568: markjay4k fourier-transform
# ### 569: markjay4k YOLO-series
# ### 570: marrrcin ml-twitter-sentiment-analysis
# ### 571: marsggbo deeplearning.ai_JupyterNotebooks
# ### 572: martin-saurer jkernel
# ### 573: masteringmatplotlib notebooks
# ### 574: mattharrison Tiny-ES6-Notebook
# ### 575: mattharrison Tiny-Python-3.6-Notebook
# ### 576: mattharrison Tiny-Python-3.8-Notebook
# ### 577: maxberggren blog-notebooks
# ### 578: maximsch2 SublimeIPythonNotebook
# ### 579: MaxinAI school-of-ai
# ### 580: maykulkarni Machine-Learning-Notebooks
# ### 581: MenNianShi deeplearning.ai
# ### 582: metakirby5 codi.vim
# ### 583: mGalarnyk Python_Tutorials
# ### 584: mgeier python-audio
# ### 585: mgroncki DataScienceNotebooks
# ### 586: mhunicken icpc-team-notebook-el-vasito
# ### 587: michaelmior calcite-notebooks
# ### 588: michhar python-jupyter-notebooks
# ### 589: michhar rpy2_sample_notebooks
# ### 590: MicroPad MicroPad-Core
# ### 591: microsoft AzureNotebooks
# ### 592: microsoft cognitive-services-notebooks
# ### 593: microsoft Cognitive-Vision-Python
# ### 594: microsoft gather
# ### 595: microsoft vscode-github-issue-notebooks
# ### 596: microsoft vscode-nodebook
# ### 597: MicrosoftDocs ml-basics
# ### 598: MicrosoftDocs mslearn-aml-labs
# ### 599: MicrosoftDocs mslearn-azure-databricks-notebooks-fundamentals
# ### 600: mietek instant-ipython
# ### 601: mikemull Notebooks
# ### 602: millejoh emacs-ipython-notebook
# ### 603: mimoralea applied-reinforcement-learning
# ### 604: minerandodados mdrepo
# ### 605: minimaxir nyc-taxi-notebook
# ### 606: minrk nbextension-scratchpad
# ### 607: Mjrovai Python4DS
# ### 608: ML-course master
# ### 609: mli d2l-1day-notebooks-zh
# ### 610: mne-tools mne-python-notebooks
# ### 611: monetate s3nb
# ### 612: Morisset Python-lectures-Notebooks
# ### 613: mozilla jupyter-notebook-gist
# ### 614: mozilla jupyter-spark
# ### 615: mrhaki Groovy-Goodness-Notebook
# ### 616: mrm8488 shared_colab_notebooks
# ### 617: msurtsukov neural-ode
# ### 618: mtianyan Programming-Notebook
# ### 619: mtl-brainhack-school-2018 teaching_material
# ### 620: muellerzr Practical-Deep-Learning-for-Coders-2.0
# ### 621: mulesoft api-notebook
# ### 622: mustafamuratcoskun Data-Analiz-Notebooklar
# ### 623: MuYunyun blog
# ### 624: mwermelinger Learn-to-code-for-data-analysis
# ### 625: mwitiderrick stockprice
# ### 626: mwouts jupytext
# ### 627: n-riesco ijavascript
# ### 628: Naereen notebooks
# ### 629: nakaizura Source-Code-Notebook
# ### 630: napsternxg ipython-notebooks
# ### 631: nate-parrott juypter-notebooks
# ### 632: nbgallery nbgallery
# ### 633: NCAR wrf_hydro_training
# ### 634: NCATS-Tangerine cq-notebooks
# ### 635: NDAR data-access-notebook
# ### 636: nebhale WhiskyNotebook
# ### 637: neilpanchal spinzero-jupyter-theme
# ### 638: neo4j-graph-analytics graph-algorithms-notebooks
# ### 639: networkx notebooks
# ### 640: NeuroTechX eeg-notebooks
# ### 641: NeuroTechX eeg-notebooks_v0.1
# ### 642: neuwangmeng Keras_Jupyter_Notebooks
# ### 643: nfultz nb2mail
# ### 644: ngoldbaum RunNotebook
# ### 645: ngthanhtrung23 ACM_Notebook_new
# ### 646: nickhould tidy-data-python
# ### 647: nicolaskruchten jupyter_pivottablejs
# ### 648: niosus notebooks
# ### 649: nipy niwidgets
# ### 650: NirantK nlp-python-deep-learning
# ### 651: nlptown nlp-notebooks
# ### 652: noaodatalab notebooks-latest
# ### 653: nsonnad base16-ipython-notebook
# ### 654: nteract commuter
# ### 655: nteract nteract
# ### 656: nteract papermill
# ### 657: nteract scrapbook
# ### 658: NumEconCopenhagen ConsumptionSavingNotebooks
# ### 659: nykma leanote-dockerfile
# ### 660: nyusterndatabootcamp notebooks
# ### 661: observablehq datasets
# ### 662: ocampor notebooks
# ### 663: ocefpaf folium_notebooks
# ### 664: ocontreras309 ML_Notebooks
# ### 665: oemof oemof-examples
# ### 666: ofermend IPython-notebooks
# ### 667: ogrisel notebooks
# ### 668: okfn-brasil notebooks
# ### 669: omarsar nlp_pytorch_tensorflow_notebooks
# ### 670: omarsar pytorch_notebooks
# ### 671: OMGZui noteBook
# ### 672: openbiox Cookbook-for-R-Chinese
# ### 673: opencubelabs notebooks
# ### 674: opendatacube datacube-notebooks
# ### 675: openearth notebooks
# ### 676: OpenFlutter Flutter-Notebook
# ### 677: OpenGeoscience geonotebook
# ### 678: OpenHumans ohjh-example-notebooks
# ### 679: oschuett appmode
# ### 680: OSGeo OSGeoLive-Notebooks
# ### 681: osigaud rl_labs_notebooks
# ### 682: OTRF notebooks-forge
# ### 683: ottomatica docable-notebooks
# ### 684: owncloud notes
# ### 685: owncloud notes-iOS-App
# ### 686: owncloud richdocuments
# ### 687: PacktPublishing Jupyter-Notebook-for-Data-Science
# ### 688: PacktPublishing Practical-Data-Analysis-using-Jupyter-Notebook
# ### 689: pangeo-data pangeo-example-notebooks
# ### 690: pangeo-data pangeo-tutorial
# ### 691: paperwork paperwork
# ### 692: parasharshah automl-handson
# ### 693: parente nbestimate
# ### 694: park-python course
# ### 695: patrickmineault xcorr-notebooks
# ### 696: patrickvonplaten notebooks
# ### 697: paulgb runipy
# ### 698: paulovn ml-vm-notebook
# ### 699: pbugnion gmaps
# ### 700: PegasusWang notebooks
# ### 701: peterroelants notebooks
# ### 702: peteryuanpan notebook
# ### 703: pgmpy pgmpy_notebook
# ### 704: philippbauch simple-linear-regression-notebook
# ### 705: piegu fastai-projects
# ### 706: pierpaolo28 Data-Visualization
# ### 707: pierrelux notebooks
# ### 708: pin3da notebook-generator
# ### 709: pink-gorilla gorilla-notebook
# ### 710: PipelineAI katacoda-notebooks
# ### 711: PipelineAI notebooks
# ### 712: pixiedust pixiedust
# ### 713: pixiedust pixiedust_node
# ### 714: planet-os notebooks
# ### 715: planetlabs notebooks
# ### 716: PlatformStories notebooks
# ### 717: plotly IPython-plotly
# ### 718: plotly jupyter-dash
# ### 719: plutov notebook
# ### 720: pm58 notebook
# ### 721: pmservice ai-openscale-tutorials
# ### 722: pnavaro python-notebooks
# ### 723: polynote polynote
# ### 724: powerpak jupyter-dark-theme
# ### 725: practical-neuroimaging pna-notebooks
# ### 726: pranjalchaubey Deep-Learning-Notes
# ### 727: pratapvardhan notebooks
# ### 728: prathameshtari Predicting-Football-Match-Outcome-using-Machine-Learning
# ### 729: prathyvsh networked-notebooks
# ### 730: probcomp notebook
# ### 731: ProgramacionCompetitivaUFPS notebook
# ### 732: propublica il-tickets-notebooks
# ### 733: psinger notebooks
# ### 734: Pulkit-Khandelwal Reinforcement-Learning-Notebooks
# ### 735: puntofisso OSMnxNotebooks
# ### 736: pybokeh jupyter_notebooks
# ### 737: Pybonacci notebooks
# ### 738: pyecharts jupyter-echarts
# ### 739: pyecharts pyecharts-users-cases
# ### 740: PYFTS notebooks
# ### 741: pyHPC pyhpc-tutorial
# ### 742: pyrech composer-changelogs
# ### 743: pysal notebooks
# ### 744: python-engineer python-engineer-notebooks
# ### 745: PythonFreeCourse Notebooks
# ### 746: qianhuihuiji notebook
# ### 747: Qiskit qiskit-tutorials
# ### 748: qiskit-community qiskit-community-tutorials
# ### 749: qtangs sagemaker-notebook-container
# ### 750: QuantConnect Research
# ### 751: QuantConnect Tutorials
# ### 752: QuantEcon lecture-python-programming.notebooks
# ### 753: QuantEcon lecture-python.notebooks
# ### 754: QuantEcon quantecon-notebooks-datascience
# ### 755: QuantEcon quantecon-notebooks-julia
# ### 756: QuantEcon quantecon-notebooks-python
# ### 757: QuantEcon QuantEcon.notebooks
# ### 758: QuantEcon sphinxcontrib-jupyter
# ### 759: quantopian qgrid
# ### 760: quantopian qgrid-notebooks
# ### 761: quantsense TimeSeries_Notebooks_Collections
# ### 762: QuantStack ipygany
# ### 763: quartiq rayopt-notebooks
# ### 764: qutip qutip-notebooks
# ### 765: R-ArcGIS R-Bridge-Tutorial-Notebooks
# ### 766: r9y9 Colaboratory
# ### 767: radanalyticsio base-notebook
# ### 768: rajathkmp Python-Lectures
# ### 769: rambasnet Python-Notebooks
# ### 770: ramnathv rNotebook
# ### 771: raphaelcruzeiro jquery-notebook
# ### 772: rapidsai notebooks
# ### 773: rapidsai-community notebooks-contrib
# ### 774: rasbt algorithms_in_ipython_notebooks
# ### 775: ravichaubey Kaggle-Notebooks
# ### 776: rayheberer LambdaSchoolDataScience
# ### 777: rdcolema nc-fish-classification
# ### 778: rdipietro jupyter-notebooks
# ### 779: red-data-tools jekyll-jupyter-notebook
# ### 780: remarkablemark universal-react-tutorial
# ### 781: renelikestacos Google-Earth-Engine-Python-Examples
# ### 782: renero class_notebooks
# ### 783: ResearchComputing xsede_2015
# ### 784: ResidentMario py_d3
# ### 785: ReviewNB treon
# ### 786: rgbkrk ipython-notebook-cookbook
# ### 787: rguthrie3 DeepLearningForNLPInPytorch
# ### 788: rhiever ipython-notebook-workshop
# ### 789: rickecon Notebooks
# ### 790: rickiepark tfk-notebooks
# ### 791: rickyzhang82 V2Ray-Deep-Packet-Inspection
# ### 792: riddhishb ipython-notebooks
# ### 793: risenW medium_tutorial_notebooks
# ### 794: rmanthey99 UdemyPython
# ### 795: rmcgibbo jupyter-emacskeys
# ### 796: robmarkcole Useful-python
# ### 797: roemmele keras-rnn-notebooks
# ### 798: rookiepeng radar-simulation-notebooks
# ### 799: root-project NotebookPrimer
# ### 800: RosettaCommons PyRosetta.notebooks
# ### 801: rossant ipymd
# ### 802: rothnic anaconda-notebook
# ### 803: rougier numpy-100
# ### 804: royalosyin Practice-SQL-with-SQLite-and-Jupyter-Notebook
# ### 805: rsignell-usgs notebook
# ### 806: rtidatascience connected-nx-tutorial
# ### 807: sachinruk deepschool.io
# ### 808: sagemath sagenb
# ### 809: SamLau95 nbinteract
# ### 810: samuelleach python-notebooks
# ### 811: sanand0 ipython-notebooks
# ### 812: SANSA-Stack SANSA-Notebooks
# ### 813: sanzgiri deeplearning.ai
# ### 814: sat28 githubcommit
# ### 815: satybald ipython-notebooks
# ### 816: saundersg Statistics-Notebook
# ### 817: schrodingers-katze notebook
# ### 818: scijava scijava-jupyter-kernel
# ### 819: scipy scipy-cookbook
# ### 820: SciRuby sciruby-notebooks
# ### 821: scoutbee pytorch-nlp-notebooks
# ### 822: sean-parent notebook
# ### 823: SELinuxProject selinux-notebook
# ### 824: seranus faceswap-notebooks
# ### 825: SergeyShk DataCamp-Projects
# ### 826: sergiogama notebook
# ### 827: sgugger Deep-Learning
# ### 828: shakedzy notebooks
# ### 829: shaoanlu deeplearning.ai-Convolutional-Neural-Networks
# ### 830: shashani-humanth Notebook-AdminPanel
# ### 831: SheffieldML notebook
# ### 832: ShixiangWang Handbook_of_biostatistic_R
# ### 833: shobulive notebook
# ### 834: ShopRunner jupyter-notify
# ### 835: ShorensteinCenter Shorenstein-Center-Notebooks
# ### 836: shreyans29 thesemicolon
# ### 837: shudima notebooks
# ### 838: siemanko 6.006-2015-notebooks
# ### 839: silentred learning-path
# ### 840: simnalamburt snucse
# ### 841: simulacre7 tensorflow-IPythonNotebook
# ### 842: sisl aa228-notebook
# ### 843: sisl algforopt-notebooks
# ### 844: skyfielders astronomy-notebooks
# ### 845: Slicer SlicerNotebooks
# ### 846: slojo404 nbconvert
# ### 847: SmirkCao Lihang
# ### 848: solliancenet microsoft-learning-paths-databricks-notebooks
# ### 849: soniclavier bigdata-notebook
# ### 850: spacetelescope notebooks
# ### 851: spark-notebook spark-notebook
# ### 852: spatialaudio nbsphinx
# ### 853: Speedml notebooks
# ### 854: spyder-ide spyder-notebook
# ### 855: SQLDBAWithABeard JupyterNotebooks
# ### 856: ssanderson notebooks
# ### 857: SSQ Coursera-Stanford-Divide-and-Conquer-Sorting-and-Searching-and-Randomized-Algorithms
# ### 858: SSQ Coursera-Stanford-Graph-Search-Shortest-Paths-and-Data-Structures
# ### 859: SSQ Coursera-Stanford-Greedy-Algorithms-Minimum-Spanning-Trees-and-Dynamic-Programming
# ### 860: stared livelossplot
# ### 861: Startupsci data-science-notebooks
# ### 862: stefanproell jupyter-notebook-docker-compose
# ### 863: stephenslab ipynb-website
# ### 864: Steven-Hewitt Entailment-with-Tensorflow
# ### 865: stevetjoa musicinformationretrieval.com
# ### 866: StingraySoftware notebooks
# ### 867: stitchfix Algorithms-Notebooks
# ### 868: stitchfix nodebook
# ### 869: stjordanis research-1
# ### 870: stream-processing-with-spark notebooks
# ### 871: StuartGordonReid Python-Notebooks
# ### 872: sujitpal statlearning-notebooks
# ### 873: sunduoqing notebook
# ### 874: sunpy tutorial-notebooks
# ### 875: sunwu51 notebook
# ### 876: super2bai TheGoProgrammingLanguage
# ### 877: SuprDewd CompetitiveProgramming
# ### 878: svartalf rust-battery
# ### 879: sympy quantum_notebooks
# ### 880: szymonmaszke vimpyter
# ### 881: taboola mdn-tensorflow-notebook-example
# ### 882: TailorDev monod
# ### 883: takluyver cite2c
# ### 884: takluyver jupyter-intro-xfel-jan17
# ### 885: takluyver mobilechelonian
# ### 886: takluyver nbopen
# ### 887: tamamu darkmatter
# ### 888: Tan-Moy medium_articles
# ### 889: tarmstrong nbdiff
# ### 890: Team334 notebooks
# ### 891: TeconomicsBlog notebooks
# ### 892: tele2-2 notebook
# ### 893: tesla809 intro-to-python-jupyter-notebooks
# ### 894: Tessellate-Imaging Pytorch_Tutorial
# ### 895: theam haskell-do
# ### 896: thibo73800 tensorflow2.0-examples
# ### 897: thomas-haslwanter statsintro_python
# ### 898: tiagoantao biopython-notebook
# ### 899: Tianxiaomo tensorflow_notebook
# ### 900: TiesdeKok ipystata
# ### 901: timkpaine paperboy
# ### 902: timsainb python_spectrograms_and_inversion
# ### 903: tirthajyoti Machine-Learning-with-Python
# ### 904: tirthajyoti Stats-Maths-with-Python
# ### 905: titipata customize_ipython_notebook
# ### 906: tkf emacs-ipython-notebook
# ### 907: tlinnet csharp-notebook
# ### 908: tnballo notebook
# ### 909: Tong-Chen notebook
# ### 910: TooNote TooNote
# ### 911: toxtli awesome-machine-learning-jupyter-notebooks-for-colab
# ### 912: transcranial jupyter-themer
# ### 913: treebeardtech treebeard
# ### 914: tritemio jupyter_notebook_beginner_guide
# ### 915: tritemio nbrun
# ### 916: trnkatomas Keras_2_examples
# ### 917: tsondt oscp
# ### 918: tugstugi dl-colab-notebooks
# ### 919: tuxu nbviewer-app
# ### 920: TwistedHardware mltutorial
# ### 921: twosigma beakerx
# ### 922: ubdsgroup mlcourse-ub-notebooks
# ### 923: uber h3-py-notebooks
# ### 924: uberwach leveling-up-jupyter
# ### 925: UCIDataScienceInitiative PredictiveModeling_withPython
# ### 926: udacity AIND-Simulated_Annealing
# ### 927: udacity CarND-Camera-Calibration
# ### 928: udacity CVND_Exercises
# ### 929: udacity CVND_Localization_Exercises
# ### 930: udacity RoboND-Camera-Calibration
# ### 931: ugik notebooks
# ### 932: ULAFF notebooks
# ### 933: unicodeveloper awesome-nextjs
# ### 934: Unidata python-workshop
# ### 935: unpingco Python-for-Probability-Statistics-and-Machine-Learning
# ### 936: unpingco Python-for-Signal-Processing
# ### 937: uosdmlab playdata-zeppelin-notebook
# ### 938: urbica gis-notebook
# ### 939: urcades notebook
# ### 940: urschrei Geopython
# ### 941: ushareng KaggleNotebooks
# ### 942: usstroot notebook
# ### 943: uwdata visualization-curriculum
# ### 944: vaibhavsagar notebooks
# ### 945: vaksakalli python_tutorials
# ### 946: Valassis-Digital-Media nbconflux
# ### 947: vatlab sos-notebook
# ### 948: vega ipyvega
# ### 949: velocyto-team velocyto-notebooks
# ### 950: viktyz iosnotebook
# ### 951: vinayak-mehta nbcommands
# ### 952: vincentherrmann wasserstein-notebook
# ### 953: vishwesh5 Quantum-Machine-Learning
# ### 954: voila-dashboards voila
# ### 955: vsbuffalo devnotes
# ### 956: vschaik Conjugate-Gradient
# ### 957: waltherg notebooks
# ### 958: WangYihang awesome-web-security
# ### 959: watson-developer-cloud assistant-improve-recommendations-notebook
# ### 960: wayanjimmy notebook
# ### 961: webdevmatics Entrust-Notebookapp
# ### 962: WeiFoo NoML
# ### 963: wenmin-wu jupyter-tabnine
# ### 964: wesm pydata-book
# ### 965: wilfredinni python-cheatsheet
# ### 966: willb fraud-notebooks
# ### 967: WillKoehrsen jupyter-notebook-extensions
# ### 968: WittyOrator JupyterNotebook
# ### 969: wix quix
# ### 970: wizardforcel data-science-notebook
# ### 971: WolframResearch WolframLanguageForJupyter
# ### 972: wrobstory sticky
# ### 973: wroscoe notebooks
# ### 974: wugenqiang NoteBook
# ### 975: wulee510505 notebook
# ### 976: wy-ei notebook
# ### 977: xiao-ren-wu notebook
# ### 978: xiayulei notebook
# ### 979: xintrea mytetra_dev
# ### 980: xtreamsrl jupytemplate
# ### 981: yaananth run-notebook
# ### 982: Yagami360 My_NoteBook
# ### 983: yandexdataschool mlhep2019
# ### 984: yanneta ML-notebooks
# ### 985: yaph ipython-notebooks
# ### 986: yassouali deeplearning.ai_notes
# ### 987: ydixon yolo_v3
# ### 988: yeseullee Data-science-design-manual-notebooks
# ### 989: yhilpisch dawp
# ### 990: yhilpisch py4fi2nd
# ### 991: yiheng notebook
# ### 992: yoavram CS1001.py
# ### 993: yokawasa databricks-notebooks
# ### 994: Yorko python_intro
# ### 995: yourwanghao CMUComputationalPhotography
# ### 996: ysyisyourbrother SYSU_Notebook
# ### 997: yuvipanda jupyter-resource-usage
# ### 998: yuvipanda simplest-notebook
# ### 999: yydcdut PhotoNoter
# ### 1000: z1ming LeetCode-Notebook
# ### 1001: zaidalyafeai Notebooks
# ### 1002: zakiso Postgraduate_notebook_for_SJTU_CS
# ### 1003: zhang14725804 notebook
# ### 1004: zhaopengme gitnote
# ### 1005: zhenbianshu notebook
# ### 1006: zhenyong notebook
# ### 1007: zjuchenyuan notebook
# ### 1008: znah notebooks
# ### 1009: zszazi awesome-collection-of-google-colab-notebooks
# ### 1010: zuopf769 notebook
# ### parsed 1011 git-projects  in 5.134 seconds ###

# %%
# build single csv from bundled data for visualising purpose
dir_base = '../data/repositories/git/'
meta_collection = '.meta/summary.json'
output_csv = '../data/database/db_04_analyzed_v02.csv'

# blobcity
dir_base = '../data/repositories/blobcity/git/'
output_csv = '../data/database/blobcity_02_analyzed.csv'

ml_treshold = 0.5

authors = os.listdir(dir_base)

p = 0

start = 0
end = 5000

runtime_start = time.time()
df = pd.DataFrame()

i = start
for author in authors:
    if os.path.isdir(os.path.join(dir_base, author)):
        
        projects = os.listdir(os.path.join(dir_base, author))
        #print(author, projects)
        for project in projects:
            #print(project)
            if p >= start:
                path = os.path.join(dir_base, author, project)
                if os.path.isdir(path):
                    #print('### ' + str(i) + ': ' + author, project)
                    # store final json
                    with open(os.path.join(path, meta_collection), 'r') as fp:
                        data = fp.read()
                        data = json.loads(data)
                        if data['ml_detected'] > ml_treshold:
                            df = df.append(data, ignore_index=True)
                    
                # count parsed projects
                i += 1

            # count projects
            p += 1
        
    # break loop
    if i>=end and True:
        break
    
runtime_end = time.time()
print('### parsed {0} git-projects  in {1} seconds ###'.format(i-start, round(runtime_end - runtime_start, 3)))

# drop duplicates
df = df.drop_duplicates(['link'])

# drop rows without link
df = df.dropna(axis=0, subset=['link'])

print(df.head())

# drop columns
df.drop(columns=['readme'], inplace=True)

df.to_csv(output_csv, sep=';', index=False)
# Out:
# ### parsed 1011 git-projects  in 4.761 seconds ###
#          author contributors           created_at  \
# 0           583            0  2020-03-15 02:19:04
# 1         aaren            6  2014-02-17 17:28:59
# 2  abhinavsagar            0  2019-06-18 14:10:12
# 3     abulbasar            2  2017-05-05 18:09:09
# 4  acgeospatial            0  2018-01-28 16:21:21
#
#                                          description  \
# 0
# 1                      Markdown <=> IPython Notebook
# 2           Sample notebooks for Kaggle competitions
# 3  notebooks with example for machine learning ex...
# 4  Sample sample scripts and notebooks on process...
#
#                                         description2 industry  \
# 0  Ã¦ÂÂºÃ¥ÂÂ¨Ã¥Â­Â¦Ã¤Â¹Â Ã§ÂºÂ¯Ã§Â®ÂÃ¦Â³ÂÃ¥Â®...     None
# 1                      Markdown <=> IPython Notebook     None
# 2           Sample notebooks for Kaggle competitions     None
# 3  notebooks with example for machine learning ex...     None
# 4  Sample sample scripts and notebooks on process...     None
#
#    language_primary                                          languages  \
# 0  Jupyter Notebook                         [Jupyter Notebook: 100.0%]
# 1  Jupyter Notebook  [Jupyter Notebook: 64.9%, Python: 33.3%, Smart...
# 2  Jupyter Notebook                         [Jupyter Notebook: 100.0%]
# 3  Jupyter Notebook             [Jupyter Notebook: 99.9%, Other: 0.1%]
# 4  Jupyter Notebook                         [Jupyter Notebook: 100.0%]
#
#         license                                               link  ...  \
# 0                 https://github.com/583/machine_learning_notebook  ...
# 1  BSD-2-Clause                  https://github.com/aaren/notedown  ...
# 2           MIT   https://github.com/abhinavsagar/kaggle-notebooks  ...
# 3    Apache-2.0      https://github.com/abulbasar/machine-learning  ...
# 4                https://github.com/acgeospatial/Satellite_Imag...  ...
#
#                                              ml_tags  \
# 0                              [KNN, NN, Regression]
# 1                                       [Regression]
# 2  [AI, ANN, CNN, CV, DL, K-Means, NN, RL, Random...
# 3  [AI, Bayesian, CV, Classification, Clustering,...
# 4         [CV, Classification, K-Means, Recommender]
#
#                                             ml_terms  name  \
# 0  [KNN, NN, classif, clustering, decision tree, ...  None
# 1                                                 []  None
# 2  [AI, NN, classif, clustering, detect, fit, k-m...  None
# 3                             [ML, machine learning]  None
# 4                             [CV, classif, k-means]  None
#
#              pushed_at                                             readme  \
# 0  2020-03-20 04:41:34  # machine_learning_notebook  机器学习算法代码实现和数据集  C...
# 1  2020-11-03 15:07:00  *Python 2/3 and IPython 4 / Jupyter compatible...
# 2  2020-09-22 15:27:59  # Kaggle Solutions Sample notebooks for Kaggle...
# 3  2020-09-10 06:32:24  # machine-learning notebooks with machine lear...
# 4  2021-01-02 15:31:39  # Satellite_Imagery_Python Sample sample scrip...
#
#             scraped_at  stars stars_score                      title  type
# 0  2020-12-19 22:36:54   13.0       0.327  machine_learning_notebook  None
# 1  2020-12-20 08:46:03  746.0       0.629                   notedown  None
# 2  2020-12-20 08:45:01   71.0       0.473           kaggle-notebooks  None
# 3  2020-12-19 23:15:29   45.0       0.437           machine-learning  None
# 4  2020-12-19 22:41:03   79.0       0.482   Satellite_Imagery_Python  None
#
# [5 rows x 22 columns]
